# %%
import numpy as np
import rasterio
import pandas as pd
import os

# 读取城市列表
cities_df = pd.read_csv('CitiesDB_new.csv')
print(f"共有 {len(cities_df)} 个城市需要处理")

# 设置阈值
threshold = 0.34

# 存储结果的列表
results = []

# 遍历所有城市
for index, row in cities_df.iterrows():
    city_name = row.iloc[0]  # 假设第一列是城市名称，根据实际情况调整
    
    # print(f"正在处理城市 {index+1}/{len(cities_df)}: {city_name}")
    
    try:
        # 构建文件路径
        image_2016_path = f"images/{city_name}_2016.tif"
        image_2023_path = f"images/{city_name}_2023.tif"
        
        # 检查文件是否存在
        if not os.path.exists(image_2016_path):
            print(f"  警告: {image_2016_path} 不存在")
            continue
        if not os.path.exists(image_2023_path):
            print(f"  警告: {image_2023_path} 不存在")
            continue
            
        # 读取2016年图像
        with rasterio.open(image_2016_path) as src:
            image_2016 = src.read(2)  # 第二个band
            
        # 读取2023年图像
        with rasterio.open(image_2023_path) as src:
            image_2023 = src.read(2)  # 第二个band
            
        # 阈值处理
        binary_2016 = (image_2016 > threshold).astype(int)
        binary_2023 = (image_2023 > threshold).astype(int)
        
        # 统计2016年
        count_0_2016 = np.sum(binary_2016 == 0)
        count_1_2016 = np.sum(binary_2016 == 1)
        total_2016 = binary_2016.size
        
        # 统计2023年
        count_0_2023 = np.sum(binary_2023 == 0)
        count_1_2023 = np.sum(binary_2023 == 1)
        total_2023 = binary_2023.size
        
        # 计算百分比
        pct_0_2016 = (count_0_2016 / total_2016) * 100
        pct_1_2016 = (count_1_2016 / total_2016) * 100
        pct_0_2023 = (count_0_2023 / total_2023) * 100
        pct_1_2023 = (count_1_2023 / total_2023) * 100
        
        # 计算变化
        change_1_count = count_1_2023 - count_1_2016
        change_1_pct = (change_1_count / count_1_2016) * 100 if count_1_2016 > 0 else 0
        
        # 存储结果
        result = {
            'City': city_name,
            'Total_Pixels_2016': total_2016,
            'Count_0_2016': count_0_2016,
            'Count_1_2016': count_1_2016,
            'Pct_0_2016': pct_0_2016,
            'Pct_1_2016': pct_1_2016,
            'Total_Pixels_2023': total_2023,
            'Count_0_2023': count_0_2023,
            'Count_1_2023': count_1_2023,
            'Pct_0_2023': pct_0_2023,
            'Pct_1_2023': pct_1_2023,
            'Change_1_Count': change_1_count,
            'Change_1_Percent': change_1_pct
        }
        
        results.append(result)
        
        # 打印当前城市的结果
        # print(f"  2016: 0={count_0_2016:,}({pct_0_2016:.1f}%), 1={count_1_2016:,}({pct_1_2016:.1f}%)")
        # print(f"  2023: 0={count_0_2023:,}({pct_0_2023:.1f}%), 1={count_1_2023:,}({pct_1_2023:.1f}%)")
        # print(f"  变化: 1的像素 {change_1_count:+,} ({change_1_pct:+.2f}%)")
        
    except Exception as e:
        print(f"  错误处理城市 {city_name}: {str(e)}")
        continue

# 转换为DataFrame并保存结果
results_df = pd.DataFrame(results)
output_file = 'threshold_analysis_results.csv'
results_df.to_csv(output_file, index=False)

print(f"\n=== 处理完成 ===")
print(f"成功处理了 {len(results_df)} 个城市")
print(f"结果已保存到: {output_file}")

# 显示汇总统计
if len(results_df) > 0:
    print(f"\n=== 汇总统计 ===")
    print(f"2016年平均1的占比: {results_df['Pct_1_2016'].mean():.2f}%")
    print(f"2023年平均1的占比: {results_df['Pct_1_2023'].mean():.2f}%")
    print(f"平均变化: {results_df['Change_1_Percent'].mean():+.2f}%")
    print(f"1的占比增长最大的城市: {results_df.loc[results_df['Change_1_Percent'].idxmax(), 'City']} ({results_df['Change_1_Percent'].max():+.2f}%)")
    print(f"1的占比减少最大的城市: {results_df.loc[results_df['Change_1_Percent'].idxmin(), 'City']} ({results_df['Change_1_Percent'].min():+.2f}%)")
    
    # 显示前5个结果作为预览
    print(f"\n=== 前5个城市结果预览 ===")
    print(results_df.head().to_string(index=False))
# Out:
# 共有 104 个城市需要处理
#
# === 处理完成 ===
# 成功处理了 104 个城市
# 结果已保存到: threshold_analysis_results.csv
#
# === 汇总统计 ===
# 2016年平均1的占比: 14.97%
# 2023年平均1的占比: 17.05%
# 平均变化: +17.37%
# 1的占比增长最大的城市: Monrovia (+54.55%)
# 1的占比减少最大的城市: Mumbai (+1.14%)
#
# === 前5个城市结果预览 ===
#         City  Total_Pixels_2016  Count_0_2016  Count_1_2016  Pct_0_2016  Pct_1_2016  Total_Pixels_2023  Count_0_2023  Count_1_2023  Pct_0_2023  Pct_1_2023  Change_1_Count  Change_1_Percent
# Antananarivo           16008001      14878123       1129878   92.941792    7.058208           16008001      14600758       1407243   91.209127    8.790873          277365         24.548226
#      Abidjan           16008001      13966725       2041276   87.248402   12.751598           16008001      13327602       2680399   83.255879   16.744121          639123         31.309975
#      Yaounde           16008001      14640706       1367295   91.458677    8.541323           16008001      14037616       1970385   87.691249   12.308751          603090         44.108258
#       Lusaka           16012002      14402029       1609973   89.945211   10.054789           16012002      13859292       2152710   86.555647   13.444353          542737         33.710938
#        Hanoi           16016003      12201871       3814132   76.185494   23.814506           16016003      11591311       4424692   72.373307   27.626693          610560         16.007836

# %%
import os
import pickle
import time
import numpy as np
import pandas as pd
import geopandas as gpd
import rasterio
import cupy as cp
import matplotlib.pyplot as plt
from tqdm import tqdm
from scipy.stats import gaussian_kde
from scipy.ndimage import uniform_filter, convolve
from shapely.geometry import Point, Polygon
import alphashape
from scipy.spatial.distance import cdist
import pyproj
from shapely.ops import transform
from functools import partial
import math
from pathlib import Path
from rasterio.transform import xy  # Import the xy function

def read_tiff(file_path):
    """Read TIFF file with enhanced debugging"""
    print(f"[DEBUG] Reading TIFF file: {file_path}")
    try:
        with rasterio.open(file_path) as src:
            data = src.read()
            meta = src.meta.copy()
            transform = src.transform
            crs = src.crs
            bounds = src.bounds  # Additional metadata

            print(f"[DEBUG] Bands: {src.count}")
            print(f"[DEBUG] Shape: {data.shape}")
            print(f"[DEBUG] CRS: {crs}")
            print(f"[DEBUG] Bounds: {bounds}")

            return data, meta, transform, crs, bounds
    except RasterioIOError as e:
        print(f"[ERROR] TIFF reading failed: {e}")
        return None

def convert_to_projected_coords(points, source_crs):
    """
    Convert points from source CRS to a suitable UTM projection
    
    Parameters:
    -----------
    points : numpy.ndarray
        Array of shape (n, 2) containing x,y coordinates
    source_crs : str or CRS
        The source coordinate reference system
    
    Returns:
    --------
    projected_points : list
        List of projected coordinates as tuples
    utm_crs : CRS
        The target UTM CRS
    """
    # Check if points array is empty using NumPy's size attribute
    if points.size == 0:
        return [], None
        
    # Convert source_crs to pyproj CRS if it's a string
    if isinstance(source_crs, str):
        source_crs = pyproj.CRS.from_string(source_crs)
    
    # Calculate the centroid of points to determine the appropriate UTM zone
    mean_lon = np.mean(points[:, 0])
    mean_lat = np.mean(points[:, 1])
    
    # Determine UTM zone based on the centroid
    utm_crs = pyproj.CRS.from_dict({
        'proj': 'utm',
        'zone': int((mean_lon + 180) / 6) + 1,
        'south': mean_lat < 0
    })
    
    # Create the transformer
    transformer = pyproj.Transformer.from_crs(source_crs, utm_crs, always_xy=True)
    
    # Transform all points
    x, y = transformer.transform(points[:, 0], points[:, 1])
    
    # Convert to a list of tuples for alphashape
    projected_points = list(zip(x, y))
    
    return projected_points, utm_crs

def haversine_distance(lat1, lon1, lat2, lon2):
    """Calculate the Haversine distance between two points on Earth"""
    # Convert coordinates to radians
    lat1, lon1, lat2, lon2 = map(np.radians, [lat1, lon1, lat2, lon2])
    
    # Haversine formula
    dlon = lon2 - lon1
    dlat = lat2 - lat1
    
    a = np.sin(dlat/2)**2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon/2)**2
    c = 2 * np.arcsin(np.sqrt(a))
    
    # Radius of Earth in kilometers
    r = 6371
    
    return c * r

def create_sliding_window_dataframe(data, transform, city_center, crs, output_dir="pixel_data",threshold=0.5):
    """
    Create a DataFrame using 3x3 sliding window analysis with vectorized operations
    Starting from row 1, col 1 (0-indexed) to ensure full 3x3 neighborhood
    """
    print(f"[DEBUG] Creating sliding window DataFrame with 3x3 windows using vectorized operations")

    # Ensure output directory exists
    os.makedirs(output_dir, exist_ok=True)

    # Extract bands
    building_height = data[1]  # Height band (band 2, 0-indexed as 1)
    building_presence = data[2]  # Building presence band (band 3, 0-indexed as 2)

    print(f"[DEBUG] Image shape: {building_presence.shape}")
    print(f"[DEBUG] Building presence range: {building_presence.min()} to {building_presence.max()}")

    # Apply threshold to create building existence binary mask
    building_exist = (building_presence > threshold).astype(int)
    print(f"[DEBUG] Building existence pixels: {np.sum(building_exist)} out of {building_exist.size}")

    # Get image dimensions
    height, width = building_presence.shape

    print(f"[DEBUG] Starting vectorized 3x3 window processing...")
    
    # Create 3x3 kernel for convolution
    kernel_3x3 = np.ones((3, 3), dtype=np.float32)
    
    building_count_full = convolve(building_exist.astype(np.float32), kernel_3x3, mode='constant', cval=0.0)
    building_count_full = building_count_full.astype(int)
    
    # For average height calculation, we need to handle division by building count
    # Use convolution to compute sum in 3x3 windows efficiently
    height_sum_full = convolve((building_height * building_exist).astype(np.float32), kernel_3x3, mode='constant', cval=0.0)
    
    # Extract the valid region (excluding border pixels)
    building_counts = building_count_full[1:-1, 1:-1]
    height_sums = height_sum_full[1:-1, 1:-1]
    
    # Calculate average heights (avoid division by zero warnings)
    avg_heights = np.divide(height_sums, building_counts, 
                           out=np.zeros_like(height_sums, dtype=float), 
                           where=building_counts > 0)
        
    print(f"[DEBUG] Vectorized window processing completed")
    
    # Generate coordinate grids for center pixels
    rows_range = np.arange(1, height - 1)
    cols_range = np.arange(1, width - 1)
    row_grid, col_grid = np.meshgrid(rows_range, cols_range, indexing='ij')
    
    # Flatten grids for output
    center_rows = row_grid.flatten()
    center_cols = col_grid.flatten()
    building_counts_flat = building_counts.flatten()
    avg_heights_flat = avg_heights.flatten()
    
    print(f"[DEBUG] Converting pixel coordinates to geographic coordinates...")
    
    # Batch convert pixel coordinates to geographic coordinates
    center_xs, center_ys = xy(transform, center_rows, center_cols, offset='center')
    
    print(f"[DEBUG] Calculating distances to city center...")
    
    # Vectorized distance calculation using numpy broadcasting
    center_ys_array = np.array(center_ys)
    center_xs_array = np.array(center_xs)
    
    # Vectorized haversine distance calculation
    lat1, lon1 = np.radians(center_ys_array), np.radians(center_xs_array)
    lat2, lon2 = np.radians(city_center[0]), np.radians(city_center[1])
    
    dlon = lon2 - lon1
    dlat = lat2 - lat1
    
    a = np.sin(dlat/2)**2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon/2)**2
    c = 2 * np.arcsin(np.sqrt(a))
    distances = c * 6371  # Earth radius in km

    # Create DataFrame
    df_windows = pd.DataFrame({
        'center_row': center_rows,
        'center_col': center_cols,
        'center_longitude': center_xs_array,
        'center_latitude': center_ys_array,
        'building_count': building_counts_flat,  # Number of pixels with buildings (0-9)
        'avg_height': avg_heights_flat,  # Average height of building pixels
        'distance_to_center': distances  # Distance to city center in km
    })

    print(f"[DEBUG] Created DataFrame with {len(df_windows)} windows")
    
    # Print statistics
    print(f"[INFO] Window analysis statistics:")
    print(f"  - Building count range: {df_windows['building_count'].min()} to {df_windows['building_count'].max()}")
    print(f"  - Average height range: {df_windows['avg_height'].min():.2f} to {df_windows['avg_height'].max():.2f}")
    print(f"  - Distance range: {df_windows['distance_to_center'].min():.2f} to {df_windows['distance_to_center'].max():.2f} km")
    print(f"  - Windows with buildings: {len(df_windows[df_windows['building_count'] > 0])}")

    return df_windows

def process_city(tiff_file, city_name, year, city_center, t):
    """Process a single city's TIFF file with 3x3 sliding window analysis"""
    print(f"[INFO] Processing {city_name} {year} with 3x3 sliding window analysis")
    
    try:
        # Create output directories
        output_dirs = ["pixel_data", "visualizations"]
        for directory in output_dirs:
            os.makedirs(directory, exist_ok=True)
        
        # Read TIFF
        print("[DEBUG] Reading TIFF file...")
        result = read_tiff(tiff_file)
        if result is not None:
            data, meta, transform, crs, bounds = result
            # Proceed with processing the data
        else:
            # Handle the error case
            print("Failed to read the TIFF file.")
            return False
            # Create sliding window DataFrame
        df_windows = create_sliding_window_dataframe(data, transform, city_center, crs, threshold = t)
        
        # Save the windows dataframe
        windows_output_file = os.path.join("aggregated_data", f"{city_name}_{year}_3x3_windows.csv")
        df_windows.to_csv(windows_output_file, index=False)
        print(f"[DEBUG] Saved {len(df_windows)} windows to {windows_output_file}")
        
        print(f"[INFO] {city_name} {year} analysis completed successfully!")
        return True
        
    except Exception as e:
        print(f"[ERROR] An error occurred while processing {city_name} {year}: {e}")
        import traceback
        traceback.print_exc()
        return False

# %%
##生成cities列表
import pandas as pd

# 读取 CSV 文件
df = pd.read_csv("CitiesDB_new.csv")

# 获取第9到第18个城市（索引为8到17）
#subset = df.iloc[50:51] #Mumbai
#subset = df.iloc[0:1]
subset = df.iloc[50:104]

# 构建 cities 列表
cities = []

# 添加从 CSV 中提取的城市
for _, row in subset.iterrows():
    city = row["Name"]
    lon = row["Cx(lon)"]
    lat = row["Cy(lat)"]
    cities.append((city, [2016, 2023], (lat, lon)))

# 打印结果验证
for c in cities:
    print(c)
# Out:
# ('Mumbai', [2016, 2023], (18.968949, 72.819119))
# ('Manila', [2016, 2023], (14.598171, 120.983366))
# ('Dhaka', [2016, 2023], (23.731382, 90.425371))
# ('Kolkata', [2016, 2023], (22.572363, 88.358792))
# ('Bangkok', [2016, 2023], (13.756876, 100.502114))
# ('Karachi', [2016, 2023], (24.849182, 67.002087))
# ('Bangalore', [2016, 2023], (12.972095, 77.594172))
# ('Ho Chi Minh City', [2016, 2023], (10.778004, 106.696322))
# ('Chennai', [2016, 2023], (13.082905, 80.274252))
# ('Hyderabad', [2016, 2023], (17.380835, 78.484755))
# ('Kuala Lumpur', [2016, 2023], (3.145446, 101.69502))
# ('Bandung', [2016, 2023], (-6.914929, 107.602485))
# ('Pune', [2016, 2023], (18.525565, 73.867503))
# ('Ahmedabad', [2016, 2023], (23.025975, 72.598625))
# ('Surat', [2016, 2023], (21.205076, 72.840369))
# ('Surabaya', [2016, 2023], (-7.243775, 112.738052))
# ('Jaipur', [2016, 2023], (26.912351, 75.819625))
# ('Phnom Penh', [2016, 2023], (11.556365, 104.92865))
# ('Denpasar', [2016, 2023], (-8.673105, 115.233856))
# ('Davao', [2016, 2023], (7.070148, 125.607648))
# ('Semarang', [2016, 2023], (-6.989227, 110.42328))
# ('Palembang', [2016, 2023], (-2.987893, 104.760804))
# ('Makassar', [2016, 2023], (-5.130501, 119.420656))
# ('Batam', [2016, 2023], (1.148084, 104.009867))
# ('Bandar Lampung', [2016, 2023], (-5.443954, 105.280374))
# ('Kathmandu', [2016, 2023], (27.709591, 85.327876))
# ('Sao Paulo', [2016, 2023], (-23.551743, -46.634937))
# ('Mexico City', [2016, 2023], (19.432273, -99.133377))
# ('Rio de Janeiro', [2016, 2023], (-22.909313, -43.180365))
# ('Lima', [2016, 2023], (-12.046023, -77.03058))
# ('Bogota', [2016, 2023], (4.597901, -74.076102))
# ('Guadalajara', [2016, 2023], (20.676609, -103.34696))
# ('Belo Horizonte', [2016, 2023], (-19.923063, -43.945842))
# ('Brasilia', [2016, 2023], (-15.79346, -47.882575))
# ('Guatemala City', [2016, 2023], (14.641789, -90.51394))
# ('Salvador', [2016, 2023], (-12.97291, -38.510074))
# ('La Paz', [2016, 2023], (-16.504085, -68.131395))
# ('Guayaquil', [2016, 2023], (-2.194852, -79.884976))
# ('Santo Domingo', [2016, 2023], (18.473583, -69.884518))
# ('Medellin', [2016, 2023], (6.251887, -75.567845))
# ('Cali', [2016, 2023], (3.454379, -76.531654))
# ('Quito', [2016, 2023], (-0.221358, -78.514987))
# ('Tegucigalpa', [2016, 2023], (14.103884, -87.205185))
# ('Leon', [2016, 2023], (21.121925, -101.682701))
# ('Puebla', [2016, 2023], (19.044369, -98.198547))
# ('San Jose', [2016, 2023], (9.933145, -84.079156))
# ('Managua', [2016, 2023], (12.129613, -86.266443))
# ('Port-au-Prince', [2016, 2023], (18.540879, -72.335196))
# ('Merida', [2016, 2023], (20.967167, -89.623728))
# ('Cancun', [2016, 2023], (21.161338, -86.824175))
# ('Queretaro', [2016, 2023], (20.59312, -100.389739))
# ('Acapulco', [2016, 2023], (16.859189, -99.872513))
# ('San Salvador', [2016, 2023], (13.698074, -89.19158))
# ('Asuncion', [2016, 2023], (-25.282896, -57.63491))

# %%
def main():
    """Process multiple cities and years"""
    
    # Define cities with their years and coordinates
    # You need to modify this list according to your actual cities
    
    # Process each city and year
    results = []
    for city_name, years, city_center in cities:
        for year in years:
            # Construct TIFF file path
            tiff_file = f"images/{city_name}_{year}.tif"
            
            # Check if file exists
            if not os.path.exists(tiff_file):
                print(f"[WARNING] TIFF file not found: {tiff_file}")
                continue
            
            # Process city (removed min_confidence parameter)
            success = process_city(tiff_file, city_name, year,  city_center,t=0.5)
            results.append({
                "city": city_name,
                "year": year,
                "success": success
            })
    
    # Print summary
    print("\n[SUMMARY] Processing Results:")
    for result in results:
        status = "SUCCESS" if result["success"] else "FAILED"
        print(f"  {result['city']} {result['year']}: {status}")

if __name__ == "__main__":
    main()
# Out:
# [INFO] Processing Mumbai 2016 with 3x3 sliding window analysis
# [DEBUG] Reading TIFF file...
# [DEBUG] Reading TIFF file: images/Mumbai_2016.tif
# [DEBUG] Bands: 3
# [DEBUG] Shape: (3, 4002, 4001)
# [DEBUG] CRS: EPSG:4326
# [DEBUG] Bounds: BoundingBox(left=72.63939084141592, bottom=18.789252314172323, right=72.99880678659214, top=19.148758090876957)
# [DEBUG] Creating sliding window DataFrame with 3x3 windows using vectorized operations
# [DEBUG] Image shape: (4002, 4001)
# [DEBUG] Building presence range: 0.0 to 1.0
# [DEBUG] Building existence pixels: 512123 out of 16012002
# [DEBUG] Starting vectorized 3x3 window processing...
# [DEBUG] Vectorized window processing completed
# [DEBUG] Converting pixel coordinates to geographic coordinates...
# [DEBUG] Calculating distances to city center...
# [DEBUG] Created DataFrame with 15996000 windows
# [INFO] Window analysis statistics:
#   - Building count range: 0 to 9
#   - Average height range: 0.00 to 99.46
#   - Distance range: 0.00 to 27.49 km
#   - Windows with buildings: 1323235
# [DEBUG] Saved 15996000 windows to aggregated_data/Mumbai_2016_3x3_windows.csv
# [INFO] Mumbai 2016 analysis completed successfully!
# [INFO] Processing Mumbai 2023 with 3x3 sliding window analysis
# [DEBUG] Reading TIFF file...
# [DEBUG] Reading TIFF file: images/Mumbai_2023.tif
# [DEBUG] Bands: 3
# [DEBUG] Shape: (3, 4002, 4001)
# [DEBUG] CRS: EPSG:4326
# [DEBUG] Bounds: BoundingBox(left=72.63939084141592, bottom=18.789252314172323, right=72.99880678659214, top=19.148758090876957)
# [DEBUG] Creating sliding window DataFrame with 3x3 windows using vectorized operations
# [DEBUG] Image shape: (4002, 4001)
# [DEBUG] Building presence range: 0.0 to 1.0
# [DEBUG] Building existence pixels: 456329 out of 16012002
# [DEBUG] Starting vectorized 3x3 window processing...
# [DEBUG] Vectorized window processing completed
# [DEBUG] Converting pixel coordinates to geographic coordinates...
# [DEBUG] Calculating distances to city center...
# [DEBUG] Created DataFrame with 15996000 windows
# [INFO] Window analysis statistics:
#   - Building count range: 0 to 9
#   - Average height range: 0.00 to 99.56
#   - Distance range: 0.00 to 27.49 km
#   - Windows with buildings: 1260869
# [DEBUG] Saved 15996000 windows to aggregated_data/Mumbai_2023_3x3_windows.csv
# [INFO] Mumbai 2023 analysis completed successfully!
# [INFO] Processing Manila 2016 with 3x3 sliding window analysis
# [DEBUG] Reading TIFF file...
# [DEBUG] Reading TIFF file: images/Manila_2016.tif
# [DEBUG] Bands: 3
# [DEBUG] Shape: (3, 4001, 4001)
# [DEBUG] CRS: EPSG:4326
# [DEBUG] Bounds: BoundingBox(left=120.803642777825, bottom=14.418499299288792, right=121.16305872300123, top=14.777915244465012)
# [DEBUG] Creating sliding window DataFrame with 3x3 windows using vectorized operations
# [DEBUG] Image shape: (4001, 4001)
# [DEBUG] Building presence range: 0.0 to 1.0
# [DEBUG] Building existence pixels: 2328738 out of 16008001
# [DEBUG] Starting vectorized 3x3 window processing...
# [DEBUG] Vectorized window processing completed
# [DEBUG] Converting pixel coordinates to geographic coordinates...
# [DEBUG] Calculating distances to city center...
# [DEBUG] Created DataFrame with 15992001 windows
# [INFO] Window analysis statistics:
#   - Building count range: 0 to 9
#   - Average height range: 0.00 to 99.34
#   - Distance range: 0.00 to 27.79 km
#   - Windows with buildings: 5024165
# [DEBUG] Saved 15992001 windows to aggregated_data/Manila_2016_3x3_windows.csv
# [INFO] Manila 2016 analysis completed successfully!
# [INFO] Processing Manila 2023 with 3x3 sliding window analysis
# [DEBUG] Reading TIFF file...
# [DEBUG] Reading TIFF file: images/Manila_2023.tif
# [DEBUG] Bands: 3
# [DEBUG] Shape: (3, 4001, 4001)
# [DEBUG] CRS: EPSG:4326
# [DEBUG] Bounds: BoundingBox(left=120.803642777825, bottom=14.418499299288792, right=121.16305872300123, top=14.777915244465012)
# [DEBUG] Creating sliding window DataFrame with 3x3 windows using vectorized operations
# [DEBUG] Image shape: (4001, 4001)
# [DEBUG] Building presence range: 0.0 to 1.0
# [DEBUG] Building existence pixels: 2517048 out of 16008001
# [DEBUG] Starting vectorized 3x3 window processing...
# [DEBUG] Vectorized window processing completed
# [DEBUG] Converting pixel coordinates to geographic coordinates...
# [DEBUG] Calculating distances to city center...
# [DEBUG] Created DataFrame with 15992001 windows
# [INFO] Window analysis statistics:
#   - Building count range: 0 to 9
#   - Average height range: 0.00 to 99.79
#   - Distance range: 0.00 to 27.79 km
#   - Windows with buildings: 5271012
# [DEBUG] Saved 15992001 windows to aggregated_data/Manila_2023_3x3_windows.csv
# [INFO] Manila 2023 analysis completed successfully!
# [INFO] Processing Dhaka 2016 with 3x3 sliding window analysis
# [DEBUG] Reading TIFF file...
# [DEBUG] Reading TIFF file: images/Dhaka_2016.tif
# [DEBUG] Bands: 3
# [DEBUG] Shape: (3, 4002, 4001)
# [DEBUG] CRS: EPSG:4326
# [DEBUG] Bounds: BoundingBox(left=90.24565175793124, bottom=23.551670792931965, right=90.60506770310747, top=23.9111765696366)
# [DEBUG] Creating sliding window DataFrame with 3x3 windows using vectorized operations
# [DEBUG] Image shape: (4002, 4001)
# [DEBUG] Building presence range: 0.0 to 1.0
# [DEBUG] Building existence pixels: 1041672 out of 16012002
# [DEBUG] Starting vectorized 3x3 window processing...
# [DEBUG] Vectorized window processing completed
# [DEBUG] Converting pixel coordinates to geographic coordinates...
# [DEBUG] Calculating distances to city center...
# [DEBUG] Created DataFrame with 15996000 windows
# [INFO] Window analysis statistics:
#   - Building count range: 0 to 9
#   - Average height range: 0.00 to 96.21
#   - Distance range: 0.00 to 27.08 km
#   - Windows with buildings: 3006813
# [DEBUG] Saved 15996000 windows to aggregated_data/Dhaka_2016_3x3_windows.csv
# [INFO] Dhaka 2016 analysis completed successfully!
# [INFO] Processing Dhaka 2023 with 3x3 sliding window analysis
# [DEBUG] Reading TIFF file...
# [DEBUG] Reading TIFF file: images/Dhaka_2023.tif
# [DEBUG] Bands: 3
# [DEBUG] Shape: (3, 4002, 4001)
# [DEBUG] CRS: EPSG:4326
# [DEBUG] Bounds: BoundingBox(left=90.24565175793124, bottom=23.551670792931965, right=90.60506770310747, top=23.9111765696366)
# [DEBUG] Creating sliding window DataFrame with 3x3 windows using vectorized operations
# [DEBUG] Image shape: (4002, 4001)
# [DEBUG] Building presence range: 0.0 to 1.0
# [DEBUG] Building existence pixels: 1273145 out of 16012002
# [DEBUG] Starting vectorized 3x3 window processing...
# [DEBUG] Vectorized window processing completed
# [DEBUG] Converting pixel coordinates to geographic coordinates...
# [DEBUG] Calculating distances to city center...
# [DEBUG] Created DataFrame with 15996000 windows
# [INFO] Window analysis statistics:
#   - Building count range: 0 to 9
#   - Average height range: 0.00 to 94.29
#   - Distance range: 0.00 to 27.08 km
#   - Windows with buildings: 3518443
# [DEBUG] Saved 15996000 windows to aggregated_data/Dhaka_2023_3x3_windows.csv
# [INFO] Dhaka 2023 analysis completed successfully!
# [INFO] Processing Kolkata 2016 with 3x3 sliding window analysis
# [DEBUG] Reading TIFF file...
# [DEBUG] Reading TIFF file: images/Kolkata_2016.tif
# [DEBUG] Bands: 3
# [DEBUG] Shape: (3, 4002, 4001)
# [DEBUG] CRS: EPSG:4326
# [DEBUG] Bounds: BoundingBox(left=88.17907744681429, bottom=22.392664413360958, right=88.53849339199051, top=22.75217019006559)
# [DEBUG] Creating sliding window DataFrame with 3x3 windows using vectorized operations
# [DEBUG] Image shape: (4002, 4001)
# [DEBUG] Building presence range: 0.0 to 1.0
# [DEBUG] Building existence pixels: 1803231 out of 16012002
# [DEBUG] Starting vectorized 3x3 window processing...
# [DEBUG] Vectorized window processing completed
# [DEBUG] Converting pixel coordinates to geographic coordinates...
# [DEBUG] Calculating distances to city center...
# [DEBUG] Created DataFrame with 15996000 windows
# [INFO] Window analysis statistics:
#   - Building count range: 0 to 9
#   - Average height range: 0.00 to 99.21
#   - Distance range: 0.00 to 27.19 km
#   - Windows with buildings: 5244196
# [DEBUG] Saved 15996000 windows to aggregated_data/Kolkata_2016_3x3_windows.csv
# [INFO] Kolkata 2016 analysis completed successfully!
# [INFO] Processing Kolkata 2023 with 3x3 sliding window analysis
# [DEBUG] Reading TIFF file...
# [DEBUG] Reading TIFF file: images/Kolkata_2023.tif
# [DEBUG] Bands: 3
# [DEBUG] Shape: (3, 4002, 4001)
# [DEBUG] CRS: EPSG:4326
# [DEBUG] Bounds: BoundingBox(left=88.17907744681429, bottom=22.392664413360958, right=88.53849339199051, top=22.75217019006559)
# [DEBUG] Creating sliding window DataFrame with 3x3 windows using vectorized operations
# [DEBUG] Image shape: (4002, 4001)
# [DEBUG] Building presence range: 0.0 to 1.0
# [DEBUG] Building existence pixels: 1868913 out of 16012002
# [DEBUG] Starting vectorized 3x3 window processing...
# [DEBUG] Vectorized window processing completed
# [DEBUG] Converting pixel coordinates to geographic coordinates...
# [DEBUG] Calculating distances to city center...
# [DEBUG] Created DataFrame with 15996000 windows
# [INFO] Window analysis statistics:
#   - Building count range: 0 to 9
#   - Average height range: 0.00 to 99.46
#   - Distance range: 0.00 to 27.19 km
#   - Windows with buildings: 5358912
# [DEBUG] Saved 15996000 windows to aggregated_data/Kolkata_2023_3x3_windows.csv
# [INFO] Kolkata 2023 analysis completed successfully!
# [INFO] Processing Bangkok 2016 with 3x3 sliding window analysis
# [DEBUG] Reading TIFF file...
# [DEBUG] Reading TIFF file: images/Bangkok_2016.tif
# [DEBUG] Bands: 3
# [DEBUG] Shape: (3, 4002, 4001)
# [DEBUG] CRS: EPSG:4326
# [DEBUG] Bounds: BoundingBox(left=100.32241362601357, bottom=13.57713720418245, right=100.6818295711898, top=13.93664298088708)
# [DEBUG] Creating sliding window DataFrame with 3x3 windows using vectorized operations
# [DEBUG] Image shape: (4002, 4001)
# [DEBUG] Building presence range: 0.0 to 1.0
# [DEBUG] Building existence pixels: 3549872 out of 16012002
# [DEBUG] Starting vectorized 3x3 window processing...
# [DEBUG] Vectorized window processing completed
# [DEBUG] Converting pixel coordinates to geographic coordinates...
# [DEBUG] Calculating distances to city center...
# [DEBUG] Created DataFrame with 15996000 windows
# [INFO] Window analysis statistics:
#   - Building count range: 0 to 9
#   - Average height range: 0.00 to 99.34
#   - Distance range: 0.00 to 27.84 km
#   - Windows with buildings: 8348735
# [DEBUG] Saved 15996000 windows to aggregated_data/Bangkok_2016_3x3_windows.csv
# [INFO] Bangkok 2016 analysis completed successfully!
# [INFO] Processing Bangkok 2023 with 3x3 sliding window analysis
# [DEBUG] Reading TIFF file...
# [DEBUG] Reading TIFF file: images/Bangkok_2023.tif
# [DEBUG] Bands: 3
# [DEBUG] Shape: (3, 4002, 4001)
# [DEBUG] CRS: EPSG:4326
# [DEBUG] Bounds: BoundingBox(left=100.32241362601357, bottom=13.57713720418245, right=100.6818295711898, top=13.93664298088708)
# [DEBUG] Creating sliding window DataFrame with 3x3 windows using vectorized operations
# [DEBUG] Image shape: (4002, 4001)
# [DEBUG] Building presence range: 0.0 to 1.0
# [DEBUG] Building existence pixels: 4025754 out of 16012002
# [DEBUG] Starting vectorized 3x3 window processing...
# [DEBUG] Vectorized window processing completed
# [DEBUG] Converting pixel coordinates to geographic coordinates...
# [DEBUG] Calculating distances to city center...
# [DEBUG] Created DataFrame with 15996000 windows
# [INFO] Window analysis statistics:
#   - Building count range: 0 to 9
#   - Average height range: 0.00 to 99.31
#   - Distance range: 0.00 to 27.84 km
#   - Windows with buildings: 9057031
# [DEBUG] Saved 15996000 windows to aggregated_data/Bangkok_2023_3x3_windows.csv
# [INFO] Bangkok 2023 analysis completed successfully!
# [INFO] Processing Karachi 2016 with 3x3 sliding window analysis
# [DEBUG] Reading TIFF file...
# [DEBUG] Reading TIFF file: images/Karachi_2016.tif
# [DEBUG] Bands: 3
# [DEBUG] Shape: (3, 4003, 4001)
# [DEBUG] CRS: EPSG:4326
# [DEBUG] Bounds: BoundingBox(left=66.82235021909996, bottom=24.669444500961887, right=67.18176616427618, top=25.02904010919493)
# [DEBUG] Creating sliding window DataFrame with 3x3 windows using vectorized operations
# [DEBUG] Image shape: (4003, 4001)
# [DEBUG] Building presence range: 0.0 to 1.0
# [DEBUG] Building existence pixels: 1524582 out of 16016003
# [DEBUG] Starting vectorized 3x3 window processing...
# [DEBUG] Vectorized window processing completed
# [DEBUG] Converting pixel coordinates to geographic coordinates...
# [DEBUG] Calculating distances to city center...
# [DEBUG] Created DataFrame with 15999999 windows
# [INFO] Window analysis statistics:
#   - Building count range: 0 to 9
#   - Average height range: 0.00 to 99.12
#   - Distance range: 0.00 to 26.98 km
#   - Windows with buildings: 3436370
# [DEBUG] Saved 15999999 windows to aggregated_data/Karachi_2016_3x3_windows.csv
# [INFO] Karachi 2016 analysis completed successfully!
# [INFO] Processing Karachi 2023 with 3x3 sliding window analysis
# [DEBUG] Reading TIFF file...
# [DEBUG] Reading TIFF file: images/Karachi_2023.tif
# [DEBUG] Bands: 3
# [DEBUG] Shape: (3, 4003, 4001)
# [DEBUG] CRS: EPSG:4326
# [DEBUG] Bounds: BoundingBox(left=66.82235021909996, bottom=24.669444500961887, right=67.18176616427618, top=25.02904010919493)
# [DEBUG] Creating sliding window DataFrame with 3x3 windows using vectorized operations
# [DEBUG] Image shape: (4003, 4001)
# [DEBUG] Building presence range: nan to nan
# [DEBUG] Building existence pixels: 1632111 out of 16016003
# [DEBUG] Starting vectorized 3x3 window processing...
# [DEBUG] Vectorized window processing completed
# [DEBUG] Converting pixel coordinates to geographic coordinates...
# [DEBUG] Calculating distances to city center...
# [DEBUG] Created DataFrame with 15999999 windows
# [INFO] Window analysis statistics:
#   - Building count range: 0 to 9
#   - Average height range: 0.00 to 97.07
#   - Distance range: 0.00 to 26.98 km
#   - Windows with buildings: 3630282
# [DEBUG] Saved 15999999 windows to aggregated_data/Karachi_2023_3x3_windows.csv
# [INFO] Karachi 2023 analysis completed successfully!
# [INFO] Processing Bangalore 2016 with 3x3 sliding window analysis
# [DEBUG] Reading TIFF file...
# [DEBUG] Reading TIFF file: images/Bangalore_2016.tif
# [DEBUG] Bands: 3
# [DEBUG] Shape: (3, 4002, 4001)
# [DEBUG] CRS: EPSG:4326
# [DEBUG] Bounds: BoundingBox(left=77.41447556568166, bottom=12.792368971975634, right=77.77389151085788, top=13.151874748680266)
# [DEBUG] Creating sliding window DataFrame with 3x3 windows using vectorized operations
# [DEBUG] Image shape: (4002, 4001)
# [DEBUG] Building presence range: 0.0 to 1.0
# [DEBUG] Building existence pixels: 1682518 out of 16012002
# [DEBUG] Starting vectorized 3x3 window processing...
# [DEBUG] Vectorized window processing completed
# [DEBUG] Converting pixel coordinates to geographic coordinates...
# [DEBUG] Calculating distances to city center...
# [DEBUG] Created DataFrame with 15996000 windows
# [INFO] Window analysis statistics:
#   - Building count range: 0 to 9
#   - Average height range: 0.00 to 99.02
#   - Distance range: 0.00 to 27.89 km
#   - Windows with buildings: 4529948
# [DEBUG] Saved 15996000 windows to aggregated_data/Bangalore_2016_3x3_windows.csv
# [INFO] Bangalore 2016 analysis completed successfully!
# [INFO] Processing Bangalore 2023 with 3x3 sliding window analysis
# [DEBUG] Reading TIFF file...
# [DEBUG] Reading TIFF file: images/Bangalore_2023.tif
# [DEBUG] Bands: 3
# [DEBUG] Shape: (3, 4002, 4001)
# [DEBUG] CRS: EPSG:4326
# [DEBUG] Bounds: BoundingBox(left=77.41447556568166, bottom=12.792368971975634, right=77.77389151085788, top=13.151874748680266)
# [DEBUG] Creating sliding window DataFrame with 3x3 windows using vectorized operations
# [DEBUG] Image shape: (4002, 4001)
# [DEBUG] Building presence range: 0.0 to 1.0
# [DEBUG] Building existence pixels: 1955541 out of 16012002
# [DEBUG] Starting vectorized 3x3 window processing...
# [DEBUG] Vectorized window processing completed
# [DEBUG] Converting pixel coordinates to geographic coordinates...
# [DEBUG] Calculating distances to city center...
# [DEBUG] Created DataFrame with 15996000 windows
# [INFO] Window analysis statistics:
#   - Building count range: 0 to 9
#   - Average height range: 0.00 to 98.79
#   - Distance range: 0.00 to 27.89 km
#   - Windows with buildings: 5171755
# [DEBUG] Saved 15996000 windows to aggregated_data/Bangalore_2023_3x3_windows.csv
# [INFO] Bangalore 2023 analysis completed successfully!
# [INFO] Processing Ho Chi Minh City 2016 with 3x3 sliding window analysis
# [DEBUG] Reading TIFF file...
# [DEBUG] Reading TIFF file: images/Ho Chi Minh City_2016.tif
# [DEBUG] Bands: 3
# [DEBUG] Shape: (3, 4001, 4001)
# [DEBUG] CRS: EPSG:4326
# [DEBUG] Bounds: BoundingBox(left=106.51665683613132, bottom=10.598323722042116, right=106.87607278130754, top=10.957739667218336)
# [DEBUG] Creating sliding window DataFrame with 3x3 windows using vectorized operations
# [DEBUG] Image shape: (4001, 4001)
# [DEBUG] Building presence range: 0.0 to 1.0
# [DEBUG] Building existence pixels: 2356090 out of 16008001
# [DEBUG] Starting vectorized 3x3 window processing...
# [DEBUG] Vectorized window processing completed
# [DEBUG] Converting pixel coordinates to geographic coordinates...
# [DEBUG] Calculating distances to city center...
# [DEBUG] Created DataFrame with 15992001 windows
# [INFO] Window analysis statistics:
#   - Building count range: 0 to 9
#   - Average height range: 0.00 to 99.38
#   - Distance range: 0.01 to 28.00 km
#   - Windows with buildings: 5280143
# [DEBUG] Saved 15992001 windows to aggregated_data/Ho Chi Minh City_2016_3x3_windows.csv
# [INFO] Ho Chi Minh City 2016 analysis completed successfully!
# [INFO] Processing Ho Chi Minh City 2023 with 3x3 sliding window analysis
# [DEBUG] Reading TIFF file...
# [DEBUG] Reading TIFF file: images/Ho Chi Minh City_2023.tif
# [DEBUG] Bands: 3
# [DEBUG] Shape: (3, 4001, 4001)
# [DEBUG] CRS: EPSG:4326
# [DEBUG] Bounds: BoundingBox(left=106.51665683613132, bottom=10.598323722042116, right=106.87607278130754, top=10.957739667218336)
# [DEBUG] Creating sliding window DataFrame with 3x3 windows using vectorized operations
# [DEBUG] Image shape: (4001, 4001)
# [DEBUG] Building presence range: 0.0 to 1.0
# [DEBUG] Building existence pixels: 2805462 out of 16008001
# [DEBUG] Starting vectorized 3x3 window processing...
# [DEBUG] Vectorized window processing completed
# [DEBUG] Converting pixel coordinates to geographic coordinates...
# [DEBUG] Calculating distances to city center...
# [DEBUG] Created DataFrame with 15992001 windows
# [INFO] Window analysis statistics:
#   - Building count range: 0 to 9
#   - Average height range: 0.00 to 99.10
#   - Distance range: 0.01 to 28.00 km
#   - Windows with buildings: 5995475
# [DEBUG] Saved 15992001 windows to aggregated_data/Ho Chi Minh City_2023_3x3_windows.csv
# [INFO] Ho Chi Minh City 2023 analysis completed successfully!
# [INFO] Processing Chennai 2016 with 3x3 sliding window analysis
# [DEBUG] Reading TIFF file...
# [DEBUG] Reading TIFF file: images/Chennai_2016.tif
# [DEBUG] Bands: 3
# [DEBUG] Shape: (3, 4001, 4001)
# [DEBUG] CRS: EPSG:4326
# [DEBUG] Bounds: BoundingBox(left=80.09450938432383, bottom=12.903221078035983, right=80.45392532950005, top=13.262637023212204)
# [DEBUG] Creating sliding window DataFrame with 3x3 windows using vectorized operations
# [DEBUG] Image shape: (4001, 4001)
# [DEBUG] Building presence range: 0.0 to 1.0
# [DEBUG] Building existence pixels: 1307446 out of 16008001
# [DEBUG] Starting vectorized 3x3 window processing...
# [DEBUG] Vectorized window processing completed
# [DEBUG] Converting pixel coordinates to geographic coordinates...
# [DEBUG] Calculating distances to city center...
# [DEBUG] Created DataFrame with 15992001 windows
# [INFO] Window analysis statistics:
#   - Building count range: 0 to 9
#   - Average height range: 0.00 to 92.94
#   - Distance range: 0.00 to 27.88 km
#   - Windows with buildings: 3446922
# [DEBUG] Saved 15992001 windows to aggregated_data/Chennai_2016_3x3_windows.csv
# [INFO] Chennai 2016 analysis completed successfully!
# [INFO] Processing Chennai 2023 with 3x3 sliding window analysis
# [DEBUG] Reading TIFF file...
# [DEBUG] Reading TIFF file: images/Chennai_2023.tif
# [DEBUG] Bands: 3
# [DEBUG] Shape: (3, 4001, 4001)
# [DEBUG] CRS: EPSG:4326
# [DEBUG] Bounds: BoundingBox(left=80.09450938432383, bottom=12.903221078035983, right=80.45392532950005, top=13.262637023212204)
# [DEBUG] Creating sliding window DataFrame with 3x3 windows using vectorized operations
# [DEBUG] Image shape: (4001, 4001)
# [DEBUG] Building presence range: 0.0 to 1.0
# [DEBUG] Building existence pixels: 1446998 out of 16008001
# [DEBUG] Starting vectorized 3x3 window processing...
# [DEBUG] Vectorized window processing completed
# [DEBUG] Converting pixel coordinates to geographic coordinates...
# [DEBUG] Calculating distances to city center...
# [DEBUG] Created DataFrame with 15992001 windows
# [INFO] Window analysis statistics:
#   - Building count range: 0 to 9
#   - Average height range: 0.00 to 97.40
#   - Distance range: 0.00 to 27.88 km
#   - Windows with buildings: 3684603
# [DEBUG] Saved 15992001 windows to aggregated_data/Chennai_2023_3x3_windows.csv
# [INFO] Chennai 2023 analysis completed successfully!
# [INFO] Processing Hyderabad 2016 with 3x3 sliding window analysis
# [DEBUG] Reading TIFF file...
# [DEBUG] Reading TIFF file: images/Hyderabad_2016.tif
# [DEBUG] Bands: 3
# [DEBUG] Shape: (3, 4002, 4001)
# [DEBUG] CRS: EPSG:4326
# [DEBUG] Bounds: BoundingBox(left=78.30506533835775, bottom=17.20112072337742, right=78.66448128353397, top=17.560626500082055)
# [DEBUG] Creating sliding window DataFrame with 3x3 windows using vectorized operations
# [DEBUG] Image shape: (4002, 4001)
# [DEBUG] Building presence range: 0.0 to 1.0
# [DEBUG] Building existence pixels: 1685724 out of 16012002
# [DEBUG] Starting vectorized 3x3 window processing...
# [DEBUG] Vectorized window processing completed
# [DEBUG] Converting pixel coordinates to geographic coordinates...
# [DEBUG] Calculating distances to city center...
# [DEBUG] Created DataFrame with 15996000 windows
# [INFO] Window analysis statistics:
#   - Building count range: 0 to 9
#   - Average height range: 0.00 to 98.84
#   - Distance range: 0.00 to 27.61 km
#   - Windows with buildings: 4357121
# [DEBUG] Saved 15996000 windows to aggregated_data/Hyderabad_2016_3x3_windows.csv
# [INFO] Hyderabad 2016 analysis completed successfully!
# [INFO] Processing Hyderabad 2023 with 3x3 sliding window analysis
# [DEBUG] Reading TIFF file...
# [DEBUG] Reading TIFF file: images/Hyderabad_2023.tif
# [DEBUG] Bands: 3
# [DEBUG] Shape: (3, 4002, 4001)
# [DEBUG] CRS: EPSG:4326
# [DEBUG] Bounds: BoundingBox(left=78.30506533835775, bottom=17.20112072337742, right=78.66448128353397, top=17.560626500082055)
# [DEBUG] Creating sliding window DataFrame with 3x3 windows using vectorized operations
# [DEBUG] Image shape: (4002, 4001)
# [DEBUG] Building presence range: 0.0 to 1.0
# [DEBUG] Building existence pixels: 1988228 out of 16012002
# [DEBUG] Starting vectorized 3x3 window processing...
# [DEBUG] Vectorized window processing completed
# [DEBUG] Converting pixel coordinates to geographic coordinates...
# [DEBUG] Calculating distances to city center...
# [DEBUG] Created DataFrame with 15996000 windows
# [INFO] Window analysis statistics:
#   - Building count range: 0 to 9
#   - Average height range: 0.00 to 98.29
#   - Distance range: 0.00 to 27.61 km
#   - Windows with buildings: 5097801
# [DEBUG] Saved 15996000 windows to aggregated_data/Hyderabad_2023_3x3_windows.csv
# [INFO] Hyderabad 2023 analysis completed successfully!
# [INFO] Processing Kuala Lumpur 2016 with 3x3 sliding window analysis
# [DEBUG] Reading TIFF file...
# [DEBUG] Reading TIFF file: images/Kuala Lumpur_2016.tif
# [DEBUG] Bands: 3
# [DEBUG] Shape: (3, 4001, 4001)
# [DEBUG] CRS: EPSG:4326
# [DEBUG] Bounds: BoundingBox(left=101.51528649179588, bottom=2.965698078992188, right=101.8747024369721, top=3.3251140241684087)
# [DEBUG] Creating sliding window DataFrame with 3x3 windows using vectorized operations
# [DEBUG] Image shape: (4001, 4001)
# [DEBUG] Building presence range: 0.0 to 1.0
# [DEBUG] Building existence pixels: 1875116 out of 16008001
# [DEBUG] Starting vectorized 3x3 window processing...
# [DEBUG] Vectorized window processing completed
# [DEBUG] Converting pixel coordinates to geographic coordinates...
# [DEBUG] Calculating distances to city center...
# [DEBUG] Created DataFrame with 15992001 windows
# [INFO] Window analysis statistics:
#   - Building count range: 0 to 9
#   - Average height range: 0.00 to 99.49
#   - Distance range: 0.01 to 28.22 km
#   - Windows with buildings: 4348909
# [DEBUG] Saved 15992001 windows to aggregated_data/Kuala Lumpur_2016_3x3_windows.csv
# [INFO] Kuala Lumpur 2016 analysis completed successfully!
# [INFO] Processing Kuala Lumpur 2023 with 3x3 sliding window analysis
# [DEBUG] Reading TIFF file...
# [DEBUG] Reading TIFF file: images/Kuala Lumpur_2023.tif
# [DEBUG] Bands: 3
# [DEBUG] Shape: (3, 4001, 4001)
# [DEBUG] CRS: EPSG:4326
# [DEBUG] Bounds: BoundingBox(left=101.51528649179588, bottom=2.965698078992188, right=101.8747024369721, top=3.3251140241684087)
# [DEBUG] Creating sliding window DataFrame with 3x3 windows using vectorized operations
# [DEBUG] Image shape: (4001, 4001)
# [DEBUG] Building presence range: 0.0 to 1.0
# [DEBUG] Building existence pixels: 2070746 out of 16008001
# [DEBUG] Starting vectorized 3x3 window processing...
# [DEBUG] Vectorized window processing completed
# [DEBUG] Converting pixel coordinates to geographic coordinates...
# [DEBUG] Calculating distances to city center...
# [DEBUG] Created DataFrame with 15992001 windows
# [INFO] Window analysis statistics:
#   - Building count range: 0 to 9
#   - Average height range: 0.00 to 99.90
#   - Distance range: 0.01 to 28.22 km
#   - Windows with buildings: 4638990
# [DEBUG] Saved 15992001 windows to aggregated_data/Kuala Lumpur_2023_3x3_windows.csv
# [INFO] Kuala Lumpur 2023 analysis completed successfully!
# [INFO] Processing Bandung 2016 with 3x3 sliding window analysis
# [DEBUG] Reading TIFF file...
# [DEBUG] Reading TIFF file: images/Bandung_2016.tif
# [DEBUG] Bands: 3
# [DEBUG] Shape: (3, 4001, 4001)
# [DEBUG] CRS: EPSG:4326
# [DEBUG] Bounds: BoundingBox(left=107.42278746322268, bottom=-7.0946246193907445, right=107.7822034083989, top=-6.735208674214524)
# [DEBUG] Creating sliding window DataFrame with 3x3 windows using vectorized operations
# [DEBUG] Image shape: (4001, 4001)
# [DEBUG] Building presence range: 0.0 to 1.0
# [DEBUG] Building existence pixels: 1916995 out of 16008001
# [DEBUG] Starting vectorized 3x3 window processing...
# [DEBUG] Vectorized window processing completed
# [DEBUG] Converting pixel coordinates to geographic coordinates...
# [DEBUG] Calculating distances to city center...
# [DEBUG] Created DataFrame with 15992001 windows
# [INFO] Window analysis statistics:
#   - Building count range: 0 to 9
#   - Average height range: 0.00 to 97.23
#   - Distance range: 0.00 to 28.14 km
#   - Windows with buildings: 4161878
# [DEBUG] Saved 15992001 windows to aggregated_data/Bandung_2016_3x3_windows.csv
# [INFO] Bandung 2016 analysis completed successfully!
# [INFO] Processing Bandung 2023 with 3x3 sliding window analysis
# [DEBUG] Reading TIFF file...
# [DEBUG] Reading TIFF file: images/Bandung_2023.tif
# [DEBUG] Bands: 3
# [DEBUG] Shape: (3, 4001, 4001)
# [DEBUG] CRS: EPSG:4326
# [DEBUG] Bounds: BoundingBox(left=107.42278746322268, bottom=-7.0946246193907445, right=107.7822034083989, top=-6.735208674214524)
# [DEBUG] Creating sliding window DataFrame with 3x3 windows using vectorized operations
# [DEBUG] Image shape: (4001, 4001)
# [DEBUG] Building presence range: 0.0 to 1.0
# [DEBUG] Building existence pixels: 2150500 out of 16008001
# [DEBUG] Starting vectorized 3x3 window processing...
# [DEBUG] Vectorized window processing completed
# [DEBUG] Converting pixel coordinates to geographic coordinates...
# [DEBUG] Calculating distances to city center...
# [DEBUG] Created DataFrame with 15992001 windows
# [INFO] Window analysis statistics:
#   - Building count range: 0 to 9
#   - Average height range: 0.00 to 96.94
#   - Distance range: 0.00 to 28.14 km
#   - Windows with buildings: 4512840
# [DEBUG] Saved 15992001 windows to aggregated_data/Bandung_2023_3x3_windows.csv
# [INFO] Bandung 2023 analysis completed successfully!
# [INFO] Processing Pune 2016 with 3x3 sliding window analysis
# [DEBUG] Reading TIFF file...
# [DEBUG] Reading TIFF file: images/Pune_2016.tif
# [DEBUG] Bands: 3
# [DEBUG] Shape: (3, 4002, 4001)
# [DEBUG] CRS: EPSG:4326
# [DEBUG] Bounds: BoundingBox(left=73.68781460951182, bottom=18.345843889930926, right=74.04723055468804, top=18.70534966663556)
# [DEBUG] Creating sliding window DataFrame with 3x3 windows using vectorized operations
# [DEBUG] Image shape: (4002, 4001)
# [DEBUG] Building presence range: 0.0 to 1.0
# [DEBUG] Building existence pixels: 919141 out of 16012002
# [DEBUG] Starting vectorized 3x3 window processing...
# [DEBUG] Vectorized window processing completed
# [DEBUG] Converting pixel coordinates to geographic coordinates...
# [DEBUG] Calculating distances to city center...
# [DEBUG] Created DataFrame with 15996000 windows
# [INFO] Window analysis statistics:
#   - Building count range: 0 to 9
#   - Average height range: 0.00 to 97.32
#   - Distance range: 0.00 to 27.53 km
#   - Windows with buildings: 2653218
# [DEBUG] Saved 15996000 windows to aggregated_data/Pune_2016_3x3_windows.csv
# [INFO] Pune 2016 analysis completed successfully!
# [INFO] Processing Pune 2023 with 3x3 sliding window analysis
# [DEBUG] Reading TIFF file...
# [DEBUG] Reading TIFF file: images/Pune_2023.tif
# [DEBUG] Bands: 3
# [DEBUG] Shape: (3, 4002, 4001)
# [DEBUG] CRS: EPSG:4326
# [DEBUG] Bounds: BoundingBox(left=73.68781460951182, bottom=18.345843889930926, right=74.04723055468804, top=18.70534966663556)
# [DEBUG] Creating sliding window DataFrame with 3x3 windows using vectorized operations
# [DEBUG] Image shape: (4002, 4001)
# [DEBUG] Building presence range: 0.0 to 1.0
# [DEBUG] Building existence pixels: 1101034 out of 16012002
# [DEBUG] Starting vectorized 3x3 window processing...
# [DEBUG] Vectorized window processing completed
# [DEBUG] Converting pixel coordinates to geographic coordinates...
# [DEBUG] Calculating distances to city center...
# [DEBUG] Created DataFrame with 15996000 windows
# [INFO] Window analysis statistics:
#   - Building count range: 0 to 9
#   - Average height range: 0.00 to 97.48
#   - Distance range: 0.00 to 27.53 km
#   - Windows with buildings: 3130447
# [DEBUG] Saved 15996000 windows to aggregated_data/Pune_2023_3x3_windows.csv
# [INFO] Pune 2023 analysis completed successfully!
# [INFO] Processing Ahmedabad 2016 with 3x3 sliding window analysis
# [DEBUG] Reading TIFF file...
# [DEBUG] Reading TIFF file: images/Ahmedabad_2016.tif
# [DEBUG] Bands: 3
# [DEBUG] Shape: (3, 4003, 4001)
# [DEBUG] CRS: EPSG:4326
# [DEBUG] Bounds: BoundingBox(left=72.41894427069299, bottom=22.846223800312906, right=72.77836021586921, top=23.20581940854595)
# [DEBUG] Creating sliding window DataFrame with 3x3 windows using vectorized operations
# [DEBUG] Image shape: (4003, 4001)
# [DEBUG] Building presence range: 0.0 to 1.0
# [DEBUG] Building existence pixels: 1054257 out of 16016003
# [DEBUG] Starting vectorized 3x3 window processing...
# [DEBUG] Vectorized window processing completed
# [DEBUG] Converting pixel coordinates to geographic coordinates...
# [DEBUG] Calculating distances to city center...
# [DEBUG] Created DataFrame with 15999999 windows
# [INFO] Window analysis statistics:
#   - Building count range: 0 to 9
#   - Average height range: 0.00 to 98.30
#   - Distance range: 0.01 to 27.15 km
#   - Windows with buildings: 2684713
# [DEBUG] Saved 15999999 windows to aggregated_data/Ahmedabad_2016_3x3_windows.csv
# [INFO] Ahmedabad 2016 analysis completed successfully!
# [INFO] Processing Ahmedabad 2023 with 3x3 sliding window analysis
# [DEBUG] Reading TIFF file...
# [DEBUG] Reading TIFF file: images/Ahmedabad_2023.tif
# [DEBUG] Bands: 3
# [DEBUG] Shape: (3, 4003, 4001)
# [DEBUG] CRS: EPSG:4326
# [DEBUG] Bounds: BoundingBox(left=72.41894427069299, bottom=22.846223800312906, right=72.77836021586921, top=23.20581940854595)
# [DEBUG] Creating sliding window DataFrame with 3x3 windows using vectorized operations
# [DEBUG] Image shape: (4003, 4001)
# [DEBUG] Building presence range: 0.0 to 1.0
# [DEBUG] Building existence pixels: 1197826 out of 16016003
# [DEBUG] Starting vectorized 3x3 window processing...
# [DEBUG] Vectorized window processing completed
# [DEBUG] Converting pixel coordinates to geographic coordinates...
# [DEBUG] Calculating distances to city center...
# [DEBUG] Created DataFrame with 15999999 windows
# [INFO] Window analysis statistics:
#   - Building count range: 0 to 9
#   - Average height range: 0.00 to 96.68
#   - Distance range: 0.01 to 27.15 km
#   - Windows with buildings: 3065199
# [DEBUG] Saved 15999999 windows to aggregated_data/Ahmedabad_2023_3x3_windows.csv
# [INFO] Ahmedabad 2023 analysis completed successfully!
# [INFO] Processing Surat 2016 with 3x3 sliding window analysis
# [DEBUG] Reading TIFF file...
# [DEBUG] Reading TIFF file: images/Surat_2016.tif
# [DEBUG] Bands: 3
# [DEBUG] Shape: (3, 4002, 4001)
# [DEBUG] CRS: EPSG:4326
# [DEBUG] Bounds: BoundingBox(left=72.66068091364956, bottom=21.025338719402637, right=73.02009685882578, top=21.38484449610727)
# [DEBUG] Creating sliding window DataFrame with 3x3 windows using vectorized operations
# [DEBUG] Image shape: (4002, 4001)
# [DEBUG] Building presence range: 0.0 to 1.0
# [DEBUG] Building existence pixels: 761920 out of 16012002
# [DEBUG] Starting vectorized 3x3 window processing...
# [DEBUG] Vectorized window processing completed
# [DEBUG] Converting pixel coordinates to geographic coordinates...
# [DEBUG] Calculating distances to city center...
# [DEBUG] Created DataFrame with 15996000 windows
# [INFO] Window analysis statistics:
#   - Building count range: 0 to 9
#   - Average height range: 0.00 to 96.53
#   - Distance range: 0.00 to 27.31 km
#   - Windows with buildings: 1760361
# [DEBUG] Saved 15996000 windows to aggregated_data/Surat_2016_3x3_windows.csv
# [INFO] Surat 2016 analysis completed successfully!
# [INFO] Processing Surat 2023 with 3x3 sliding window analysis
# [DEBUG] Reading TIFF file...
# [DEBUG] Reading TIFF file: images/Surat_2023.tif
# [DEBUG] Bands: 3
# [DEBUG] Shape: (3, 4002, 4001)
# [DEBUG] CRS: EPSG:4326
# [DEBUG] Bounds: BoundingBox(left=72.66068091364956, bottom=21.025338719402637, right=73.02009685882578, top=21.38484449610727)
# [DEBUG] Creating sliding window DataFrame with 3x3 windows using vectorized operations
# [DEBUG] Image shape: (4002, 4001)
# [DEBUG] Building presence range: 0.0 to 1.0
# [DEBUG] Building existence pixels: 862057 out of 16012002
# [DEBUG] Starting vectorized 3x3 window processing...
# [DEBUG] Vectorized window processing completed
# [DEBUG] Converting pixel coordinates to geographic coordinates...
# [DEBUG] Calculating distances to city center...
# [DEBUG] Created DataFrame with 15996000 windows
# [INFO] Window analysis statistics:
#   - Building count range: 0 to 9
#   - Average height range: 0.00 to 95.44
#   - Distance range: 0.00 to 27.31 km
#   - Windows with buildings: 2018816
# [DEBUG] Saved 15996000 windows to aggregated_data/Surat_2023_3x3_windows.csv
# [INFO] Surat 2023 analysis completed successfully!
# [INFO] Processing Surabaya 2016 with 3x3 sliding window analysis
# [DEBUG] Reading TIFF file...
# [DEBUG] Reading TIFF file: images/Surabaya_2016.tif
# [DEBUG] Bands: 3
# [DEBUG] Shape: (3, 4001, 4001)
# [DEBUG] CRS: EPSG:4326
# [DEBUG] Bounds: BoundingBox(left=112.55836611100557, bottom=-7.423497844906901, right=112.91778205618179, top=-7.064081899730681)
# [DEBUG] Creating sliding window DataFrame with 3x3 windows using vectorized operations
# [DEBUG] Image shape: (4001, 4001)
# [DEBUG] Building presence range: 0.0 to 1.0
# [DEBUG] Building existence pixels: 1847183 out of 16008001
# [DEBUG] Starting vectorized 3x3 window processing...
# [DEBUG] Vectorized window processing completed
# [DEBUG] Converting pixel coordinates to geographic coordinates...
# [DEBUG] Calculating distances to city center...
# [DEBUG] Created DataFrame with 15992001 windows
# [INFO] Window analysis statistics:
#   - Building count range: 0 to 9
#   - Average height range: 0.00 to 98.85
#   - Distance range: 0.00 to 28.13 km
#   - Windows with buildings: 3687096
# [DEBUG] Saved 15992001 windows to aggregated_data/Surabaya_2016_3x3_windows.csv
# [INFO] Surabaya 2016 analysis completed successfully!
# [INFO] Processing Surabaya 2023 with 3x3 sliding window analysis
# [DEBUG] Reading TIFF file...
# [DEBUG] Reading TIFF file: images/Surabaya_2023.tif
# [DEBUG] Bands: 3
# [DEBUG] Shape: (3, 4001, 4001)
# [DEBUG] CRS: EPSG:4326
# [DEBUG] Bounds: BoundingBox(left=112.55836611100557, bottom=-7.423497844906901, right=112.91778205618179, top=-7.064081899730681)
# [DEBUG] Creating sliding window DataFrame with 3x3 windows using vectorized operations
# [DEBUG] Image shape: (4001, 4001)
# [DEBUG] Building presence range: 0.0 to 1.0
# [DEBUG] Building existence pixels: 2062181 out of 16008001
# [DEBUG] Starting vectorized 3x3 window processing...
# [DEBUG] Vectorized window processing completed
# [DEBUG] Converting pixel coordinates to geographic coordinates...
# [DEBUG] Calculating distances to city center...
# [DEBUG] Created DataFrame with 15992001 windows
# [INFO] Window analysis statistics:
#   - Building count range: 0 to 9
#   - Average height range: 0.00 to 98.84
#   - Distance range: 0.00 to 28.13 km
#   - Windows with buildings: 4024625
# [DEBUG] Saved 15992001 windows to aggregated_data/Surabaya_2023_3x3_windows.csv
# [INFO] Surabaya 2023 analysis completed successfully!
# [INFO] Processing Jaipur 2016 with 3x3 sliding window analysis
# [DEBUG] Reading TIFF file...
# [DEBUG] Reading TIFF file: images/Jaipur_2016.tif
# [DEBUG] Bands: 3
# [DEBUG] Shape: (3, 4003, 4001)
# [DEBUG] CRS: EPSG:4326
# [DEBUG] Bounds: BoundingBox(left=75.63994355343195, bottom=26.732605213999193, right=75.99935949860817, top=27.092200822232236)
# [DEBUG] Creating sliding window DataFrame with 3x3 windows using vectorized operations
# [DEBUG] Image shape: (4003, 4001)
# [DEBUG] Building presence range: 0.0 to 1.0
# [DEBUG] Building existence pixels: 972673 out of 16016003
# [DEBUG] Starting vectorized 3x3 window processing...
# [DEBUG] Vectorized window processing completed
# [DEBUG] Converting pixel coordinates to geographic coordinates...
# [DEBUG] Calculating distances to city center...
# [DEBUG] Created DataFrame with 15999999 windows
# [INFO] Window analysis statistics:
#   - Building count range: 0 to 9
#   - Average height range: 0.00 to 81.33
#   - Distance range: 0.00 to 26.77 km
#   - Windows with buildings: 2743127
# [DEBUG] Saved 15999999 windows to aggregated_data/Jaipur_2016_3x3_windows.csv
# [INFO] Jaipur 2016 analysis completed successfully!
# [INFO] Processing Jaipur 2023 with 3x3 sliding window analysis
# [DEBUG] Reading TIFF file...
# [DEBUG] Reading TIFF file: images/Jaipur_2023.tif
# [DEBUG] Bands: 3
# [DEBUG] Shape: (3, 4003, 4001)
# [DEBUG] CRS: EPSG:4326
# [DEBUG] Bounds: BoundingBox(left=75.63994355343195, bottom=26.732605213999193, right=75.99935949860817, top=27.092200822232236)
# [DEBUG] Creating sliding window DataFrame with 3x3 windows using vectorized operations
# [DEBUG] Image shape: (4003, 4001)
# [DEBUG] Building presence range: 0.0 to 1.0
# [DEBUG] Building existence pixels: 1157474 out of 16016003
# [DEBUG] Starting vectorized 3x3 window processing...
# [DEBUG] Vectorized window processing completed
# [DEBUG] Converting pixel coordinates to geographic coordinates...
# [DEBUG] Calculating distances to city center...
# [DEBUG] Created DataFrame with 15999999 windows
# [INFO] Window analysis statistics:
#   - Building count range: 0 to 9
#   - Average height range: 0.00 to 82.96
#   - Distance range: 0.00 to 26.77 km
#   - Windows with buildings: 3270490
# [DEBUG] Saved 15999999 windows to aggregated_data/Jaipur_2023_3x3_windows.csv
# [INFO] Jaipur 2023 analysis completed successfully!
# [INFO] Processing Phnom Penh 2016 with 3x3 sliding window analysis
# [DEBUG] Reading TIFF file...
# [DEBUG] Reading TIFF file: images/Phnom Penh_2016.tif
# [DEBUG] Bands: 3
# [DEBUG] Shape: (3, 4002, 4001)
# [DEBUG] CRS: EPSG:4326
# [DEBUG] Bounds: BoundingBox(left=104.74895202004092, bottom=11.376624084203268, right=105.10836796521714, top=11.7361298609079)
# [DEBUG] Creating sliding window DataFrame with 3x3 windows using vectorized operations
# [DEBUG] Image shape: (4002, 4001)
# [DEBUG] Building presence range: 0.0 to 1.0
# [DEBUG] Building existence pixels: 783968 out of 16012002
# [DEBUG] Starting vectorized 3x3 window processing...
# [DEBUG] Vectorized window processing completed
# [DEBUG] Converting pixel coordinates to geographic coordinates...
# [DEBUG] Calculating distances to city center...
# [DEBUG] Created DataFrame with 15996000 windows
# [INFO] Window analysis statistics:
#   - Building count range: 0 to 9
#   - Average height range: 0.00 to 98.15
#   - Distance range: 0.00 to 27.96 km
#   - Windows with buildings: 1934730
# [DEBUG] Saved 15996000 windows to aggregated_data/Phnom Penh_2016_3x3_windows.csv
# [INFO] Phnom Penh 2016 analysis completed successfully!
# [INFO] Processing Phnom Penh 2023 with 3x3 sliding window analysis
# [DEBUG] Reading TIFF file...
# [DEBUG] Reading TIFF file: images/Phnom Penh_2023.tif
# [DEBUG] Bands: 3
# [DEBUG] Shape: (3, 4002, 4001)
# [DEBUG] CRS: EPSG:4326
# [DEBUG] Bounds: BoundingBox(left=104.74895202004092, bottom=11.376624084203268, right=105.10836796521714, top=11.7361298609079)
# [DEBUG] Creating sliding window DataFrame with 3x3 windows using vectorized operations
# [DEBUG] Image shape: (4002, 4001)
# [DEBUG] Building presence range: 0.0 to 1.0
# [DEBUG] Building existence pixels: 1231777 out of 16012002
# [DEBUG] Starting vectorized 3x3 window processing...
# [DEBUG] Vectorized window processing completed
# [DEBUG] Converting pixel coordinates to geographic coordinates...
# [DEBUG] Calculating distances to city center...
# [DEBUG] Created DataFrame with 15996000 windows
# [INFO] Window analysis statistics:
#   - Building count range: 0 to 9
#   - Average height range: 0.00 to 98.98
#   - Distance range: 0.00 to 27.96 km
#   - Windows with buildings: 2817230
# [DEBUG] Saved 15996000 windows to aggregated_data/Phnom Penh_2023_3x3_windows.csv
# [INFO] Phnom Penh 2023 analysis completed successfully!
# [INFO] Processing Denpasar 2016 with 3x3 sliding window analysis
# [DEBUG] Reading TIFF file...
# [DEBUG] Reading TIFF file: images/Denpasar_2016.tif
# [DEBUG] Bands: 3
# [DEBUG] Shape: (3, 4001, 4001)
# [DEBUG] CRS: EPSG:4326
# [DEBUG] Bounds: BoundingBox(left=115.05415546487484, bottom=-8.852807293469471, right=115.41357141005106, top=-8.493391348293251)
# [DEBUG] Creating sliding window DataFrame with 3x3 windows using vectorized operations
# [DEBUG] Image shape: (4001, 4001)
# [DEBUG] Building presence range: 0.0 to 1.0
# [DEBUG] Building existence pixels: 1082630 out of 16008001
# [DEBUG] Starting vectorized 3x3 window processing...
# [DEBUG] Vectorized window processing completed
# [DEBUG] Converting pixel coordinates to geographic coordinates...
# [DEBUG] Calculating distances to city center...
# [DEBUG] Created DataFrame with 15992001 windows
# [INFO] Window analysis statistics:
#   - Building count range: 0 to 9
#   - Average height range: 0.00 to 68.77
#   - Distance range: 0.00 to 28.08 km
#   - Windows with buildings: 2722055
# [DEBUG] Saved 15992001 windows to aggregated_data/Denpasar_2016_3x3_windows.csv
# [INFO] Denpasar 2016 analysis completed successfully!
# [INFO] Processing Denpasar 2023 with 3x3 sliding window analysis
# [DEBUG] Reading TIFF file...
# [DEBUG] Reading TIFF file: images/Denpasar_2023.tif
# [DEBUG] Bands: 3
# [DEBUG] Shape: (3, 4001, 4001)
# [DEBUG] CRS: EPSG:4326
# [DEBUG] Bounds: BoundingBox(left=115.05415546487484, bottom=-8.852807293469471, right=115.41357141005106, top=-8.493391348293251)
# [DEBUG] Creating sliding window DataFrame with 3x3 windows using vectorized operations
# [DEBUG] Image shape: (4001, 4001)
# [DEBUG] Building presence range: 0.0 to 1.0
# [DEBUG] Building existence pixels: 1294383 out of 16008001
# [DEBUG] Starting vectorized 3x3 window processing...
# [DEBUG] Vectorized window processing completed
# [DEBUG] Converting pixel coordinates to geographic coordinates...
# [DEBUG] Calculating distances to city center...
# [DEBUG] Created DataFrame with 15992001 windows
# [INFO] Window analysis statistics:
#   - Building count range: 0 to 9
#   - Average height range: 0.00 to 89.05
#   - Distance range: 0.00 to 28.08 km
#   - Windows with buildings: 3046745
# [DEBUG] Saved 15992001 windows to aggregated_data/Denpasar_2023_3x3_windows.csv
# [INFO] Denpasar 2023 analysis completed successfully!
# [INFO] Processing Davao 2016 with 3x3 sliding window analysis
# [DEBUG] Reading TIFF file...
# [DEBUG] Reading TIFF file: images/Davao_2016.tif
# [DEBUG] Bands: 3
# [DEBUG] Shape: (3, 4001, 4001)
# [DEBUG] CRS: EPSG:4326
# [DEBUG] Bounds: BoundingBox(left=125.42790036588707, bottom=6.890437555310378, right=125.7873163110633, top=7.249853500486598)
# [DEBUG] Creating sliding window DataFrame with 3x3 windows using vectorized operations
# [DEBUG] Image shape: (4001, 4001)
# [DEBUG] Building presence range: 0.0 to 1.0
# [DEBUG] Building existence pixels: 329694 out of 16008001
# [DEBUG] Starting vectorized 3x3 window processing...
# [DEBUG] Vectorized window processing completed
# [DEBUG] Converting pixel coordinates to geographic coordinates...
# [DEBUG] Calculating distances to city center...
# [DEBUG] Created DataFrame with 15992001 windows
# [INFO] Window analysis statistics:
#   - Building count range: 0 to 9
#   - Average height range: 0.00 to 98.03
#   - Distance range: 0.00 to 28.14 km
#   - Windows with buildings: 1005712
# [DEBUG] Saved 15992001 windows to aggregated_data/Davao_2016_3x3_windows.csv
# [INFO] Davao 2016 analysis completed successfully!
# [INFO] Processing Davao 2023 with 3x3 sliding window analysis
# [DEBUG] Reading TIFF file...
# [DEBUG] Reading TIFF file: images/Davao_2023.tif
# [DEBUG] Bands: 3
# [DEBUG] Shape: (3, 4001, 4001)
# [DEBUG] CRS: EPSG:4326
# [DEBUG] Bounds: BoundingBox(left=125.42790036588707, bottom=6.890437555310378, right=125.7873163110633, top=7.249853500486598)
# [DEBUG] Creating sliding window DataFrame with 3x3 windows using vectorized operations
# [DEBUG] Image shape: (4001, 4001)
# [DEBUG] Building presence range: 0.0 to 1.0
# [DEBUG] Building existence pixels: 451786 out of 16008001
# [DEBUG] Starting vectorized 3x3 window processing...
# [DEBUG] Vectorized window processing completed
# [DEBUG] Converting pixel coordinates to geographic coordinates...
# [DEBUG] Calculating distances to city center...
# [DEBUG] Created DataFrame with 15992001 windows
# [INFO] Window analysis statistics:
#   - Building count range: 0 to 9
#   - Average height range: 0.00 to 94.91
#   - Distance range: 0.00 to 28.14 km
#   - Windows with buildings: 1304968
# [DEBUG] Saved 15992001 windows to aggregated_data/Davao_2023_3x3_windows.csv
# [INFO] Davao 2023 analysis completed successfully!
# [INFO] Processing Semarang 2016 with 3x3 sliding window analysis
# [DEBUG] Reading TIFF file...
# [DEBUG] Reading TIFF file: images/Semarang_2016.tif
# [DEBUG] Bands: 3
# [DEBUG] Shape: (3, 4001, 4001)
# [DEBUG] CRS: EPSG:4326
# [DEBUG] Bounds: BoundingBox(left=110.24358728688638, bottom=-7.168915293387429, right=110.6030032320626, top=-6.809499348211209)
# [DEBUG] Creating sliding window DataFrame with 3x3 windows using vectorized operations
# [DEBUG] Image shape: (4001, 4001)
# [DEBUG] Building presence range: 0.0 to 1.0
# [DEBUG] Building existence pixels: 1048559 out of 16008001
# [DEBUG] Starting vectorized 3x3 window processing...
# [DEBUG] Vectorized window processing completed
# [DEBUG] Converting pixel coordinates to geographic coordinates...
# [DEBUG] Calculating distances to city center...
# [DEBUG] Created DataFrame with 15992001 windows
# [INFO] Window analysis statistics:
#   - Building count range: 0 to 9
#   - Average height range: 0.00 to 77.22
#   - Distance range: 0.00 to 28.14 km
#   - Windows with buildings: 2503763
# [DEBUG] Saved 15992001 windows to aggregated_data/Semarang_2016_3x3_windows.csv
# [INFO] Semarang 2016 analysis completed successfully!
# [INFO] Processing Semarang 2023 with 3x3 sliding window analysis
# [DEBUG] Reading TIFF file...
# [DEBUG] Reading TIFF file: images/Semarang_2023.tif
# [DEBUG] Bands: 3
# [DEBUG] Shape: (3, 4001, 4001)
# [DEBUG] CRS: EPSG:4326
# [DEBUG] Bounds: BoundingBox(left=110.24358728688638, bottom=-7.168915293387429, right=110.6030032320626, top=-6.809499348211209)
# [DEBUG] Creating sliding window DataFrame with 3x3 windows using vectorized operations
# [DEBUG] Image shape: (4001, 4001)
# [DEBUG] Building presence range: 0.0 to 1.0
# [DEBUG] Building existence pixels: 1240641 out of 16008001
# [DEBUG] Starting vectorized 3x3 window processing...
# [DEBUG] Vectorized window processing completed
# [DEBUG] Converting pixel coordinates to geographic coordinates...
# [DEBUG] Calculating distances to city center...
# [DEBUG] Created DataFrame with 15992001 windows
# [INFO] Window analysis statistics:
#   - Building count range: 0 to 9
#   - Average height range: 0.00 to 81.17
#   - Distance range: 0.00 to 28.14 km
#   - Windows with buildings: 2801679
# ...
# [DEBUG] Starting vectorized 3x3 window processing...
# [DEBUG] Vectorized window processing completed
# [DEBUG] Converting pixel coordinates to geographic coordinates...
# [DEBUG] Calculating distances to city center...
# [DEBUG] Created DataFrame with 15996000 windows
# [INFO] Window analysis statistics:
#   - Building count range: 0 to 9
#   - Average height range: 0.00 to 93.97
#   - Distance range: 0.00 to 27.33 km
#   - Windows with buildings: 1852679
# [DEBUG] Saved 15996000 windows to aggregated_data/Merida_2016_3x3_windows.csv
# [INFO] Merida 2016 analysis completed successfully!
# [INFO] Processing Merida 2023 with 3x3 sliding window analysis
# [DEBUG] Reading TIFF file...
# [DEBUG] Reading TIFF file: images/Merida_2023.tif
# [DEBUG] Bands: 3
# [DEBUG] Shape: (3, 4002, 4001)
# [DEBUG] CRS: EPSG:4326
# [DEBUG] Bounds: BoundingBox(left=-89.8034111435592, bottom=20.787464832167785, right=-89.44399519838298, top=21.14697060887242)
# [DEBUG] Creating sliding window DataFrame with 3x3 windows using vectorized operations
# [DEBUG] Image shape: (4002, 4001)
# [DEBUG] Building presence range: 0.0 to 1.0
# [DEBUG] Building existence pixels: 691518 out of 16012002
# [DEBUG] Starting vectorized 3x3 window processing...
# [DEBUG] Vectorized window processing completed
# [DEBUG] Converting pixel coordinates to geographic coordinates...
# [DEBUG] Calculating distances to city center...
# [DEBUG] Created DataFrame with 15996000 windows
# [INFO] Window analysis statistics:
#   - Building count range: 0 to 9
#   - Average height range: 0.00 to 91.38
#   - Distance range: 0.00 to 27.33 km
#   - Windows with buildings: 2114607
# [DEBUG] Saved 15996000 windows to aggregated_data/Merida_2023_3x3_windows.csv
# [INFO] Merida 2023 analysis completed successfully!
# [INFO] Processing Cancun 2016 with 3x3 sliding window analysis
# [DEBUG] Reading TIFF file...
# [DEBUG] Reading TIFF file: images/Cancun_2016.tif
# [DEBUG] Bands: 3
# [DEBUG] Shape: (3, 4002, 4001)
# [DEBUG] CRS: EPSG:4326
# [DEBUG] Bounds: BoundingBox(left=-87.00390139212914, bottom=20.981590765066013, right=-86.64448544695291, top=21.341096541770646)
# [DEBUG] Creating sliding window DataFrame with 3x3 windows using vectorized operations
# [DEBUG] Image shape: (4002, 4001)
# [DEBUG] Building presence range: 0.0 to 1.0
# [DEBUG] Building existence pixels: 242462 out of 16012002
# [DEBUG] Starting vectorized 3x3 window processing...
# [DEBUG] Vectorized window processing completed
# [DEBUG] Converting pixel coordinates to geographic coordinates...
# [DEBUG] Calculating distances to city center...
# [DEBUG] Created DataFrame with 15996000 windows
# [INFO] Window analysis statistics:
#   - Building count range: 0 to 9
#   - Average height range: 0.00 to 96.25
#   - Distance range: 0.00 to 27.32 km
#   - Windows with buildings: 719128
# [DEBUG] Saved 15996000 windows to aggregated_data/Cancun_2016_3x3_windows.csv
# [INFO] Cancun 2016 analysis completed successfully!
# [INFO] Processing Cancun 2023 with 3x3 sliding window analysis
# [DEBUG] Reading TIFF file...
# [DEBUG] Reading TIFF file: images/Cancun_2023.tif
# [DEBUG] Bands: 3
# [DEBUG] Shape: (3, 4002, 4001)
# [DEBUG] CRS: EPSG:4326
# [DEBUG] Bounds: BoundingBox(left=-87.00390139212914, bottom=20.981590765066013, right=-86.64448544695291, top=21.341096541770646)
# [DEBUG] Creating sliding window DataFrame with 3x3 windows using vectorized operations
# [DEBUG] Image shape: (4002, 4001)
# [DEBUG] Building presence range: 0.0 to 1.0
# [DEBUG] Building existence pixels: 292514 out of 16012002
# [DEBUG] Starting vectorized 3x3 window processing...
# [DEBUG] Vectorized window processing completed
# [DEBUG] Converting pixel coordinates to geographic coordinates...
# [DEBUG] Calculating distances to city center...
# [DEBUG] Created DataFrame with 15996000 windows
# [INFO] Window analysis statistics:
#   - Building count range: 0 to 9
#   - Average height range: 0.00 to 92.33
#   - Distance range: 0.00 to 27.32 km
#   - Windows with buildings: 851312
# [DEBUG] Saved 15996000 windows to aggregated_data/Cancun_2023_3x3_windows.csv
# [INFO] Cancun 2023 analysis completed successfully!
# [INFO] Processing Queretaro 2016 with 3x3 sliding window analysis
# [DEBUG] Reading TIFF file...
# [DEBUG] Reading TIFF file: images/Queretaro_2016.tif
# [DEBUG] Bands: 3
# [DEBUG] Shape: (3, 4002, 4001)
# [DEBUG] CRS: EPSG:4326
# [DEBUG] Bounds: BoundingBox(left=-100.56945032914643, bottom=20.413406347860416, right=-100.21003438397021, top=20.77291212456505)
# [DEBUG] Creating sliding window DataFrame with 3x3 windows using vectorized operations
# [DEBUG] Image shape: (4002, 4001)
# [DEBUG] Building presence range: 0.0 to 1.0
# [DEBUG] Building existence pixels: 603741 out of 16012002
# [DEBUG] Starting vectorized 3x3 window processing...
# [DEBUG] Vectorized window processing completed
# [DEBUG] Converting pixel coordinates to geographic coordinates...
# [DEBUG] Calculating distances to city center...
# [DEBUG] Created DataFrame with 15996000 windows
# [INFO] Window analysis statistics:
#   - Building count range: 0 to 9
#   - Average height range: 0.00 to 97.36
#   - Distance range: 0.00 to 27.36 km
#   - Windows with buildings: 1735551
# [DEBUG] Saved 15996000 windows to aggregated_data/Queretaro_2016_3x3_windows.csv
# [INFO] Queretaro 2016 analysis completed successfully!
# [INFO] Processing Queretaro 2023 with 3x3 sliding window analysis
# [DEBUG] Reading TIFF file...
# [DEBUG] Reading TIFF file: images/Queretaro_2023.tif
# [DEBUG] Bands: 3
# [DEBUG] Shape: (3, 4002, 4001)
# [DEBUG] CRS: EPSG:4326
# [DEBUG] Bounds: BoundingBox(left=-100.56945032914643, bottom=20.413406347860416, right=-100.21003438397021, top=20.77291212456505)
# [DEBUG] Creating sliding window DataFrame with 3x3 windows using vectorized operations
# [DEBUG] Image shape: (4002, 4001)
# [DEBUG] Building presence range: 0.0 to 1.0
# [DEBUG] Building existence pixels: 765841 out of 16012002
# [DEBUG] Starting vectorized 3x3 window processing...
# [DEBUG] Vectorized window processing completed
# [DEBUG] Converting pixel coordinates to geographic coordinates...
# [DEBUG] Calculating distances to city center...
# [DEBUG] Created DataFrame with 15996000 windows
# [INFO] Window analysis statistics:
#   - Building count range: 0 to 9
#   - Average height range: 0.00 to 97.06
#   - Distance range: 0.00 to 27.36 km
#   - Windows with buildings: 2119525
# [DEBUG] Saved 15996000 windows to aggregated_data/Queretaro_2023_3x3_windows.csv
# [INFO] Queretaro 2023 analysis completed successfully!
# [INFO] Processing Acapulco 2016 with 3x3 sliding window analysis
# [DEBUG] Reading TIFF file...
# [DEBUG] Reading TIFF file: images/Acapulco_2016.tif
# [DEBUG] Bands: 3
# [DEBUG] Shape: (3, 4002, 4001)
# [DEBUG] CRS: EPSG:4326
# [DEBUG] Bounds: BoundingBox(left=-100.05220038855042, bottom=16.679469037889213, right=-99.6927844433742, top=17.038974814593846)
# [DEBUG] Creating sliding window DataFrame with 3x3 windows using vectorized operations
# [DEBUG] Image shape: (4002, 4001)
# [DEBUG] Building presence range: 0.0 to 1.0
# [DEBUG] Building existence pixels: 232337 out of 16012002
# [DEBUG] Starting vectorized 3x3 window processing...
# [DEBUG] Vectorized window processing completed
# [DEBUG] Converting pixel coordinates to geographic coordinates...
# [DEBUG] Calculating distances to city center...
# [DEBUG] Created DataFrame with 15996000 windows
# [INFO] Window analysis statistics:
#   - Building count range: 0 to 9
#   - Average height range: 0.00 to 97.18
#   - Distance range: 0.00 to 27.65 km
#   - Windows with buildings: 774859
# [DEBUG] Saved 15996000 windows to aggregated_data/Acapulco_2016_3x3_windows.csv
# [INFO] Acapulco 2016 analysis completed successfully!
# [INFO] Processing Acapulco 2023 with 3x3 sliding window analysis
# [DEBUG] Reading TIFF file...
# [DEBUG] Reading TIFF file: images/Acapulco_2023.tif
# [DEBUG] Bands: 3
# [DEBUG] Shape: (3, 4002, 4001)
# [DEBUG] CRS: EPSG:4326
# [DEBUG] Bounds: BoundingBox(left=-100.05220038855042, bottom=16.679469037889213, right=-99.6927844433742, top=17.038974814593846)
# [DEBUG] Creating sliding window DataFrame with 3x3 windows using vectorized operations
# [DEBUG] Image shape: (4002, 4001)
# [DEBUG] Building presence range: 0.0 to 1.0
# [DEBUG] Building existence pixels: 258059 out of 16012002
# [DEBUG] Starting vectorized 3x3 window processing...
# [DEBUG] Vectorized window processing completed
# [DEBUG] Converting pixel coordinates to geographic coordinates...
# [DEBUG] Calculating distances to city center...
# [DEBUG] Created DataFrame with 15996000 windows
# [INFO] Window analysis statistics:
#   - Building count range: 0 to 9
#   - Average height range: 0.00 to 96.82
#   - Distance range: 0.00 to 27.65 km
#   - Windows with buildings: 830556
# [DEBUG] Saved 15996000 windows to aggregated_data/Acapulco_2023_3x3_windows.csv
# [INFO] Acapulco 2023 analysis completed successfully!
# [INFO] Processing San Salvador 2016 with 3x3 sliding window analysis
# [DEBUG] Reading TIFF file...
# [DEBUG] Reading TIFF file: images/San Salvador_2016.tif
# [DEBUG] Bands: 3
# [DEBUG] Shape: (3, 4001, 4001)
# [DEBUG] CRS: EPSG:4326
# [DEBUG] Bounds: BoundingBox(left=-89.37132149189772, bottom=13.51838738460103, right=-89.0119055467215, top=13.877803329777251)
# [DEBUG] Creating sliding window DataFrame with 3x3 windows using vectorized operations
# [DEBUG] Image shape: (4001, 4001)
# [DEBUG] Building presence range: 0.0 to 1.0
# [DEBUG] Building existence pixels: 607835 out of 16008001
# [DEBUG] Starting vectorized 3x3 window processing...
# [DEBUG] Vectorized window processing completed
# [DEBUG] Converting pixel coordinates to geographic coordinates...
# [DEBUG] Calculating distances to city center...
# [DEBUG] Created DataFrame with 15992001 windows
# [INFO] Window analysis statistics:
#   - Building count range: 0 to 9
#   - Average height range: 0.00 to 95.99
#   - Distance range: 0.00 to 27.85 km
#   - Windows with buildings: 1692509
# [DEBUG] Saved 15992001 windows to aggregated_data/San Salvador_2016_3x3_windows.csv
# [INFO] San Salvador 2016 analysis completed successfully!
# [INFO] Processing San Salvador 2023 with 3x3 sliding window analysis
# [DEBUG] Reading TIFF file...
# [DEBUG] Reading TIFF file: images/San Salvador_2023.tif
# [DEBUG] Bands: 3
# [DEBUG] Shape: (3, 4001, 4001)
# [DEBUG] CRS: EPSG:4326
# [DEBUG] Bounds: BoundingBox(left=-89.37132149189772, bottom=13.51838738460103, right=-89.0119055467215, top=13.877803329777251)
# [DEBUG] Creating sliding window DataFrame with 3x3 windows using vectorized operations
# [DEBUG] Image shape: (4001, 4001)
# [DEBUG] Building presence range: 0.0 to 1.0
# [DEBUG] Building existence pixels: 680840 out of 16008001
# [DEBUG] Starting vectorized 3x3 window processing...
# [DEBUG] Vectorized window processing completed
# [DEBUG] Converting pixel coordinates to geographic coordinates...
# [DEBUG] Calculating distances to city center...
# [DEBUG] Created DataFrame with 15992001 windows
# [INFO] Window analysis statistics:
#   - Building count range: 0 to 9
#   - Average height range: 0.00 to 98.46
#   - Distance range: 0.00 to 27.85 km
#   - Windows with buildings: 1906563
# [DEBUG] Saved 15992001 windows to aggregated_data/San Salvador_2023_3x3_windows.csv
# [INFO] San Salvador 2023 analysis completed successfully!
# [INFO] Processing Asuncion 2016 with 3x3 sliding window analysis
# [DEBUG] Reading TIFF file...
# [DEBUG] Reading TIFF file: images/Asuncion_2016.tif
# [DEBUG] Bands: 3
# [DEBUG] Shape: (3, 4003, 4001)
# [DEBUG] CRS: EPSG:4326
# [DEBUG] Bounds: BoundingBox(left=-57.81458353911987, bottom=-25.462746728367836, right=-57.45516759394365, top=-25.103151120134793)
# [DEBUG] Creating sliding window DataFrame with 3x3 windows using vectorized operations
# [DEBUG] Image shape: (4003, 4001)
# [DEBUG] Building presence range: 0.0 to 1.0
# [DEBUG] Building existence pixels: 742319 out of 16016003
# [DEBUG] Starting vectorized 3x3 window processing...
# [DEBUG] Vectorized window processing completed
# [DEBUG] Converting pixel coordinates to geographic coordinates...
# [DEBUG] Calculating distances to city center...
# [DEBUG] Created DataFrame with 15999999 windows
# [INFO] Window analysis statistics:
#   - Building count range: 0 to 9
#   - Average height range: 0.00 to 96.54
#   - Distance range: 0.01 to 26.93 km
#   - Windows with buildings: 2579482
# [DEBUG] Saved 15999999 windows to aggregated_data/Asuncion_2016_3x3_windows.csv
# [INFO] Asuncion 2016 analysis completed successfully!
# [INFO] Processing Asuncion 2023 with 3x3 sliding window analysis
# [DEBUG] Reading TIFF file...
# [DEBUG] Reading TIFF file: images/Asuncion_2023.tif
# [DEBUG] Bands: 3
# [DEBUG] Shape: (3, 4003, 4001)
# [DEBUG] CRS: EPSG:4326
# [DEBUG] Bounds: BoundingBox(left=-57.81458353911987, bottom=-25.462746728367836, right=-57.45516759394365, top=-25.103151120134793)
# [DEBUG] Creating sliding window DataFrame with 3x3 windows using vectorized operations
# [DEBUG] Image shape: (4003, 4001)
# [DEBUG] Building presence range: 0.0 to 1.0
# [DEBUG] Building existence pixels: 902551 out of 16016003
# [DEBUG] Starting vectorized 3x3 window processing...
# [DEBUG] Vectorized window processing completed
# [DEBUG] Converting pixel coordinates to geographic coordinates...
# [DEBUG] Calculating distances to city center...
# [DEBUG] Created DataFrame with 15999999 windows
# [INFO] Window analysis statistics:
#   - Building count range: 0 to 9
#   - Average height range: 0.00 to 94.49
#   - Distance range: 0.01 to 26.93 km
#   - Windows with buildings: 2958174
# [DEBUG] Saved 15999999 windows to aggregated_data/Asuncion_2023_3x3_windows.csv
# [INFO] Asuncion 2023 analysis completed successfully!
#
# [SUMMARY] Processing Results:
#   Mumbai 2016: SUCCESS
#   Mumbai 2023: SUCCESS
#   Manila 2016: SUCCESS
#   Manila 2023: SUCCESS
#   Dhaka 2016: SUCCESS
#   Dhaka 2023: SUCCESS
#   Kolkata 2016: SUCCESS
#   Kolkata 2023: SUCCESS
#   Bangkok 2016: SUCCESS
#   Bangkok 2023: SUCCESS
#   Karachi 2016: SUCCESS
#   Karachi 2023: SUCCESS
#   Bangalore 2016: SUCCESS
#   Bangalore 2023: SUCCESS
#   Ho Chi Minh City 2016: SUCCESS
#   Ho Chi Minh City 2023: SUCCESS
#   Chennai 2016: SUCCESS
#   Chennai 2023: SUCCESS
#   Hyderabad 2016: SUCCESS
#   Hyderabad 2023: SUCCESS
#   Kuala Lumpur 2016: SUCCESS
#   Kuala Lumpur 2023: SUCCESS
#   Bandung 2016: SUCCESS
#   Bandung 2023: SUCCESS
#   Pune 2016: SUCCESS
#   Pune 2023: SUCCESS
#   Ahmedabad 2016: SUCCESS
#   Ahmedabad 2023: SUCCESS
#   Surat 2016: SUCCESS
#   Surat 2023: SUCCESS
#   Surabaya 2016: SUCCESS
#   Surabaya 2023: SUCCESS
#   Jaipur 2016: SUCCESS
#   Jaipur 2023: SUCCESS
#   Phnom Penh 2016: SUCCESS
#   Phnom Penh 2023: SUCCESS
#   Denpasar 2016: SUCCESS
#   Denpasar 2023: SUCCESS
#   Davao 2016: SUCCESS
#   Davao 2023: SUCCESS
#   Semarang 2016: SUCCESS
#   Semarang 2023: SUCCESS
#   Palembang 2016: SUCCESS
#   Palembang 2023: SUCCESS
#   Makassar 2016: SUCCESS
#   Makassar 2023: SUCCESS
#   Batam 2016: SUCCESS
#   Batam 2023: SUCCESS
#   Bandar Lampung 2016: SUCCESS
#   Bandar Lampung 2023: SUCCESS
#   Kathmandu 2016: SUCCESS
#   Kathmandu 2023: SUCCESS
#   Sao Paulo 2016: SUCCESS
#   Sao Paulo 2023: SUCCESS
#   Mexico City 2016: SUCCESS
#   Mexico City 2023: SUCCESS
#   Rio de Janeiro 2016: SUCCESS
#   Rio de Janeiro 2023: SUCCESS
#   Lima 2016: SUCCESS
#   Lima 2023: SUCCESS
#   Bogota 2016: SUCCESS
#   Bogota 2023: SUCCESS
#   Guadalajara 2016: SUCCESS
#   Guadalajara 2023: SUCCESS
#   Belo Horizonte 2016: SUCCESS
#   Belo Horizonte 2023: SUCCESS
#   Brasilia 2016: SUCCESS
#   Brasilia 2023: SUCCESS
#   Guatemala City 2016: SUCCESS
#   Guatemala City 2023: SUCCESS
#   Salvador 2016: SUCCESS
#   Salvador 2023: SUCCESS
#   La Paz 2016: SUCCESS
#   La Paz 2023: SUCCESS
#   Guayaquil 2016: SUCCESS
#   Guayaquil 2023: SUCCESS
#   Santo Domingo 2016: SUCCESS
#   Santo Domingo 2023: SUCCESS
#   Medellin 2016: SUCCESS
#   Medellin 2023: SUCCESS
#   Cali 2016: SUCCESS
#   Cali 2023: SUCCESS
#   Quito 2016: SUCCESS
#   Quito 2023: SUCCESS
#   Tegucigalpa 2016: SUCCESS
#   Tegucigalpa 2023: SUCCESS
#   Leon 2016: SUCCESS
#   Leon 2023: SUCCESS
#   Puebla 2016: SUCCESS
#   Puebla 2023: SUCCESS
#   San Jose 2016: SUCCESS
#   San Jose 2023: SUCCESS
#   Managua 2016: SUCCESS
#   Managua 2023: SUCCESS
#   Port-au-Prince 2016: SUCCESS
#   Port-au-Prince 2023: SUCCESS
#   Merida 2016: SUCCESS
#   Merida 2023: SUCCESS
#   Cancun 2016: SUCCESS
#   Cancun 2023: SUCCESS
#   Queretaro 2016: SUCCESS
#   Queretaro 2023: SUCCESS
#   Acapulco 2016: SUCCESS
#   Acapulco 2023: SUCCESS
#   San Salvador 2016: SUCCESS
#   San Salvador 2023: SUCCESS
#   Asuncion 2016: SUCCESS
#   Asuncion 2023: SUCCESS

# %% [markdown]
# # Unused functions

# %% [markdown]
# ## Alpha Shape

# %%
def create_alpha_shape(points, source_crs, alpha_meters=None, bw=None):
    """Create alpha shape from points using approach adapted from R"""
    print(f"[DEBUG] Creating alpha shape")
    start_time = time.time()
    
    try:
        # Create a DataFrame from the points for sampling
        df = pd.DataFrame(points, columns=['x', 'y'])
        
        # Sample points (equivalent to R's sample.int)
        sample_size = min(df.shape[0], 10000)
        if sample_size < df.shape[0]:
            v = np.random.choice(df.shape[0], size=sample_size, replace=False)
            subset = df.iloc[v]
        else:
            subset = df
        
        # Get unique x,y pairs
        u = subset[['x', 'y']].drop_duplicates()
        
        # Add small random noise (as in the R code)
        u_with_noise = u.values + np.random.normal(0, 1/1000, u.shape)
        
        print(f"[DEBUG] Computing alpha shape with {len(u_with_noise)} points")
        
        # Convert to projected coordinates - pass the coordinates directly, not Point objects
        projected_points, utm_crs = convert_to_projected_coords(u_with_noise, source_crs)
        
        # Compute alpha shape
        # If bw is provided, use it to calculate alpha as in R
        if bw is not None:
            alpha = 3 * bw
            print(f"[DEBUG] Using R-style alpha calculation: alpha = {alpha}")
        else:
            alpha = alpha_meters
            print(f"[DEBUG] Using provided alpha: alpha = {alpha}")
        
        alpha_shape = alphashape.alphashape(projected_points, alpha)
        
        # Create a GeoDataFrame with the alpha shape
        gdf_alpha = gpd.GeoDataFrame(geometry=[alpha_shape], crs=utm_crs)
        
        # Project back to original CRS
        gdf_original = gdf_alpha.to_crs(source_crs)
        
        alpha_shape_original = gdf_original.geometry.iloc[0]
        
        end_time = time.time()
        print(f"[DEBUG] Alpha shape created in {end_time - start_time:.2f} seconds")
        
        return alpha_shape_original
    except Exception as e:
        print(f"[ERROR] Alpha shape creation failed: {e}")
        raise

def save_alpha_shape(alpha_shape, city_name, year, output_dir="alpha_shapes"):
    """Save alpha shape to a pickle file with city and year information"""
    # Create output directory if it doesn't exist
    os.makedirs(output_dir, exist_ok=True)
    
    filename = os.path.join(output_dir, f"{city_name}_{year}_alpha_shape.pkl")
    print(f"[DEBUG] Saving alpha shape to {filename}")
    
    try:
        with open(filename, 'wb') as f:
            pickle.dump(alpha_shape, f)
        print("[DEBUG] Alpha shape saved successfully")
    except Exception as e:
        print(f"[ERROR] Failed to save alpha shape: {e}")

def load_alpha_shape(city_name, year, input_dir="alpha_shapes"):
    """Load alpha shape from a pickle file with city and year information"""
    filename = os.path.join(input_dir, f"{city_name}_{year}_alpha_shape.pkl")
    print(f"[DEBUG] Attempting to load alpha shape from {filename}")
    
    try:
        if os.path.exists(filename):
            with open(filename, 'rb') as f:
                alpha_shape = pickle.load(f)
            print("[DEBUG] Alpha shape loaded successfully")
            return alpha_shape
        else:
            print("[WARNING] Alpha shape file not found")
            return None
    except Exception as e:
        print(f"[ERROR] Failed to load alpha shape: {e}")
        return None

def filter_pixels_inside_alpha_hull(data, transform, alpha_hull, city_center, crs, threshold=0.34, output_dir="pixel_data"):
    """
    Filter pixels inside the alpha hull and calculate building metrics with efficient spatial indexing
    """
    print(f"[DEBUG] Efficiently filtering pixels inside alpha hull with threshold > {threshold}")

    # Ensure output directory exists
    os.makedirs(output_dir, exist_ok=True)

    # Extract bands
    building_height = data[1]  # Height band (band 2)
    building_presence = data[2]  # Presence band (band 3)

    # Create a mask for pixels with minimum presence
    presence_mask = building_presence > 0

    # Get coordinates of all potential pixels in one batch operation
    rows, cols = np.where(presence_mask)

    print(f"[DEBUG] Found {len(rows)} potential pixels with presence > 0")
    print("[DEBUG] Converting to coordinates...")

    # Fast batch conversion of pixel indices to coordinates
    xs, ys = xy(transform, rows, cols, offset='center')

    # Create points DataFrame
    points_df = pd.DataFrame({
        'row': rows,
        'col': cols,
        'longitude': xs,
        'latitude': ys
    })

    # Create GeoDataFrame with Point geometries
    print("[DEBUG] Creating GeoDataFrame for spatial filtering...")
    geometry = [Point(x, y) for x, y in zip(xs, ys)]
    gdf = gpd.GeoDataFrame(points_df, geometry=geometry, crs=crs)

    # Efficient spatial query to find points inside the alpha hull
    print("[DEBUG] Performing spatial join...")
    alpha_gdf = gpd.GeoDataFrame(geometry=[alpha_hull], crs=crs)
    points_inside = gpd.sjoin(gdf, alpha_gdf, predicate='within')

    print(f"[DEBUG] Found {len(points_inside)} points inside alpha hull")

    # Now get the building data for these points and calculate metrics
    print("[DEBUG] Calculating building metrics...")

    # Extract rows and columns for points inside the hull
    inside_rows = points_inside['row'].values
    inside_cols = points_inside['col'].values

    # Batch extract values
    presence_values = building_presence[inside_rows, inside_cols]
    height_values = building_height[inside_rows, inside_cols]

    # Apply threshold to determine building existence
    building_exists = (presence_values > threshold).astype(int)

    # Calculate building volumes
    building_volumes = height_values * building_exists

    # Calculate distances to city center
    # Convert the coordinates to arrays for vectorized haversine calculation
    lat_array = points_inside['latitude'].values
    lon_array = points_inside['longitude'].values

    # Vectorized haversine calculation
    lat1, lon1 = np.radians(lat_array), np.radians(lon_array)
    lat2, lon2 = np.radians(city_center[0]), np.radians(city_center[1])

    dlon = lon2 - lon1
    dlat = lat2 - lat1

    a = np.sin(dlat/2)**2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon/2)**2
    c = 2 * np.arcsin(np.sqrt(a))
    distances = c * 6371  # Earth radius in km

    # Create DataFrame with all metrics
    df_pixels = pd.DataFrame({
        'longitude': points_inside['longitude'].values,
        'latitude': points_inside['latitude'].values,
        'row': inside_rows,
        'col': inside_cols,
        'building_presence': presence_values,
        'building_height': height_values,
        'building_exist': building_exists,
        'building_volume': building_volumes,
        'distance_to_center': distances
    })

    print(f"[DEBUG] Processed {len(df_pixels)} pixels inside the alpha hull")

    return df_pixels

# %% [markdown]
# ## Volume Kernel Density Estimation

# %%
def generate_volume_density_map(df, city_name, year, bw=None, output_dir="density_maps"):
    """Volume density map function using pixel data"""
    # Ensure output directory exists
    os.makedirs(output_dir, exist_ok=True)

    # Verify DataFrame has data
    if df.empty:
        print("[ERROR] Cannot generate density map - empty DataFrame")
        return

    # Verify enough data points
    if len(df) < 2:
        print("[ERROR] Insufficient data points for kernel density estimation")
        return

    print("[DEBUG] Computing volume kernel density")

    try:
        # Use logarithmic scaling for better visualization
        log_volumes = np.log1p(df['building_volume'])

        # Kernel density estimation
        print(f"[DEBUG] Preparing density estimation")
        print(f"  Volume data points: {len(df)}")
        print(f"  Log volumes shape: {log_volumes.shape}")

        # Use 2D coordinates for density estimation
        coords = df[['longitude', 'latitude']].values

        print(f"[DEBUG] Coordinates shape: {coords.shape}")

        # Create grid for density map
        x_grid, y_grid = np.meshgrid(
            np.linspace(df['longitude'].min(), df['longitude'].max(), 200),
            np.linspace(df['latitude'].min(), df['latitude'].max(), 200)
        )

        # Kernel density estimation with R-style bandwidth if provided
        if bw is not None:
            print(f"[DEBUG] Using R-style bandwidth: {bw} for KDE")
            # Use Scott's rule to adjust bandwidth
            scott_factor = len(coords)**(-1/6)
            # Convert geographical bandwidth to KDE bandwidth parameter
            kde_bandwidth = bw * scott_factor
            kde = gaussian_kde(coords.T, weights=log_volumes, bw_method=kde_bandwidth)
        else:
            # Use default bandwidth
            kde = gaussian_kde(coords.T, weights=log_volumes)

        # Compute density
        grid_coords = np.vstack([x_grid.ravel(), y_grid.ravel()])
        density_values = kde(grid_coords).reshape(x_grid.shape)

        # Save the density values and grid coordinates
        density_data = {
            'x_grid': x_grid,
            'y_grid': y_grid,
            'density_values': density_values,
            'bandwidth': kde.factor if bw is None else kde_bandwidth
        }
        density_output_file = os.path.join(output_dir, f"{city_name}_{year}_density_data.pkl")
        with open(density_output_file, 'wb') as f:
            pickle.dump(density_data, f)
        print(f"[DEBUG] Density data saved to: {density_output_file}")

        # Plot density map with contours
        plt.figure(figsize=(12, 10))

        # Plot density as a heat map
        im = plt.imshow(density_values, extent=[x_grid.min(), x_grid.max(), y_grid.min(), y_grid.max()],
                   origin='lower', cmap='viridis', alpha=0.7)

        # Add contours
        contours = plt.contour(x_grid, y_grid, density_values,
                              levels=10, colors='white', alpha=0.8, linewidths=0.5)
        plt.clabel(contours, inline=True, fontsize=8, fmt='%.2f')

        plt.colorbar(im, label='Log Volume Density')
        plt.title(f'Building Volume Density Map - {city_name} {year}')
        plt.xlabel('Longitude')
        plt.ylabel('Latitude')

        # Save figure
        output_file = os.path.join(output_dir, f"{city_name}_{year}_volume_density_map.png")
        plt.savefig(output_file)
        plt.close()

        print(f"[DEBUG] Volume density map generated successfully: {output_file}")

    except Exception as e:
        print(f"[ERROR] Volume density map generation failed: {e}")
        import traceback
        traceback.print_exc()

# %% [markdown]
# ## Visualize relationship

# %%
def visualize_relationships(df, city_name, year, output_dir="visualizations"):
    """Create scatter plots for building metrics vs distance to center"""
    # Ensure output directory exists
    os.makedirs(output_dir, exist_ok=True)
    
    # Ensure DataFrame is not empty
    if df.empty:
        print("[ERROR] Cannot visualize empty DataFrame")
        return
    
    # Verify required columns exist
    required_columns = ['distance_to_center', 'building_exist', 'building_height', 'building_volume']
    missing_columns = [col for col in required_columns if col not in df.columns]
    
    if missing_columns:
        print(f"[ERROR] Missing columns: {missing_columns}")
        print("Available columns:", list(df.columns))
        return
    
    # Create multi-panel plot
    fig, axs = plt.subplots(2, 3, figsize=(15, 10))
    
    # Scatter plots
    metrics = ['building_exist', 'building_height', 'building_volume']
    for i, metric in enumerate(metrics):
        # Metric vs Distance
        axs[0, i].scatter(df['distance_to_center'], df[metric], alpha=0.5, s=1)
        axs[0, i].set_title(f'{metric.capitalize()} vs Distance to Center')
        axs[0, i].set_xlabel('Distance to City Center (km)')
        axs[0, i].set_ylabel(metric.capitalize())
    
    # Metric distribution
    for i, metric in enumerate(metrics):
        axs[1, i].hist(df[metric], bins=30)
        axs[1, i].set_title(f'{metric.capitalize()} Distribution')
        axs[1, i].set_xlabel(metric.capitalize())
        axs[1, i].set_ylabel('Frequency')
    
    plt.tight_layout()
    plt.suptitle(f'Building Metrics Analysis - {city_name} {year}', y=1.02)
    
    # Save figure
    output_file = os.path.join(output_dir, f"{city_name}_{year}_building_metrics_analysis.png")
    plt.savefig(output_file)
    plt.close()
    
    print(f"[DEBUG] Relationship visualization completed: {output_file}")

# %% [markdown]
# ## How to Call Alpha shape & Kernel (previous version)

# %%
def process_city(tiff_file, city_name, year, city_center, threshold=0.34):
    """Process a single city's TIFF file"""
    print(f"[INFO] Processing {city_name} {year} with threshold {threshold}")
    
    try:
        # Create output directories
        output_dirs = ["alpha_shapes", "pixel_data", "density_maps", "visualizations"]
        for directory in output_dirs:
            os.makedirs(directory, exist_ok=True)
        
        # Read TIFF
        print("[DEBUG] Reading TIFF file...")
        result = read_tiff(tiff_file)
        if result is not None:
            data, meta, transform, crs, bounds = result
            # Proceed with processing the data
        else:
            # Handle the error case
            print("Failed to read the TIFF file.")
            return False
        
        # Create full pixels DataFrame (add this line)
        df_all_pixels = create_full_pixels_dataframe(data, transform, city_center, crs, threshold=threshold)
        
        # Save the all pixels dataframe with city and year info (add this line)
        all_pixels_output_file = os.path.join("pixel_data", f"{city_name}_{year}_all_pixels_data.csv")
        df_all_pixels.to_csv(all_pixels_output_file, index=False)
        print(f"[DEBUG] Saved {len(df_all_pixels)} total pixels to {all_pixels_output_file}")
        
        # # Continue with the rest of your processing...
        # # Extract building points and data
        # print("[DEBUG] Extracting building points...")
        # points, heights, rows, cols = extract_building_points(data, transform, threshold=threshold)
        
        # # Extract building points and data
        # print("[DEBUG] Extracting building points...")
        # points, heights, rows, cols = extract_building_points(data, transform, threshold=threshold)
        
        # # Create DataFrame from points for calculating bandwidth
        # df_points = pd.DataFrame(points, columns=['x', 'y'])
        
        # # Calculate bandwidth as in the R code
        # bw = 0.001/np.cos(np.mean(df_points['y'])/90*np.pi/2)
        # print(f"[DEBUG] Calculated bandwidth: {bw}")
        
        # # Try to load existing alpha shape
        # alpha_hull = load_alpha_shape(city_name, year)
        
        # # If no existing alpha shape, create and save one
        # if alpha_hull is None:
        #     # Create alpha hull using R-style approach with calculated bw
        #     print("[DEBUG] Creating alpha shape...")
        #     alpha_hull = create_alpha_shape(points, crs, bw=bw)
            
        #     # Save the newly created alpha shape
        #     save_alpha_shape(alpha_hull, city_name, year)
        
        # # Filter pixels inside alpha hull and calculate metrics
        # print("[DEBUG] Filtering pixels inside alpha hull...")
        # df_pixels = filter_pixels_inside_alpha_hull(data, transform, alpha_hull, city_center, crs, threshold=threshold)
        
        # # Save pixel data
        # pixel_output_file = os.path.join("pixel_data", f"{city_name}_{year}_pixel_data.csv")
        # df_pixels.to_csv(pixel_output_file, index=False)
        # print(f"[DEBUG] Saved {len(df_pixels)} pixels to {pixel_output_file}")
        
        # # Visualize relationships
        # print("[DEBUG] Visualizing relationships...")
        # visualize_relationships(df_pixels, city_name, year)
        
        # # Generate volume density map with contours (using R-style bw)
        # # print("[DEBUG] Generating volume density map...")
        # # generate_volume_density_map(df_pixels, city_name, year, bw=bw)
        
        # # Visualize alpha hull
        # gdf_hull = gpd.GeoDataFrame(geometry=[alpha_hull], crs=crs)
        # plt.figure(figsize=(12, 10))
        # gdf_hull.plot(alpha=0.5, edgecolor='red')
        # plt.title(f'{city_name} {year} Building Alpha Hull')
        # plt.xlabel('Longitude')
        # plt.ylabel('Latitude')
        # hull_output_file = os.path.join("visualizations", f"{city_name}_{year}_alpha_hull.png")
        # plt.savefig(hull_output_file)
        # plt.close()
        
        print(f"[INFO] {city_name} {year} analysis completed successfully!")
        return True
        
    except Exception as e:
        print(f"[ERROR] An error occurred while processing {city_name} {year}: {e}")
        import traceback
        traceback.print_exc()
        return False

# %%
def main():
    """Process multiple cities and years"""
    # Define cities and their data
    # Format: [city_name, [years], (city_center_lat, city_center_lon)]
    cities = [
        # City name, list of years, (latitude, longitude) of city center
        #("Abidjan", [2016, 2023], (5.3252258, -4.019603))
        # ("Antananarivo", [2016, 2023], (-18.9155584, 47.5216452))
        # ("Yaounde", [2016, 2023], (3.8614776, 11.5191364))
        ("Lusaka", [2016, 2023], (-15.4191874, 28.3054202))
        # Add more cities as needed
    ]
    
    # Default threshold for building presence
    threshold = 0.34
    
    # Process each city and year
    results = []
    for city_name, years, city_center in cities:
        for year in years:
            # Construct TIFF file path
            tiff_file = f"{city_name}_{year}.tif"
            
            # Check if file exists
            if not os.path.exists(tiff_file):
                print(f"[WARNING] TIFF file not found: {tiff_file}")
                continue
            
            # Process city with specified threshold
            success = process_city(tiff_file, city_name, year, city_center, threshold=threshold)
            results.append({
                "city": city_name,
                "year": year,
                "success": success
            })
    
    # Print summary
    print("\n[SUMMARY] Processing Results:")
    for result in results:
        status = "SUCCESS" if result["success"] else "FAILED"
        print(f"  {result['city']} {result['year']}: {status}")

if __name__ == "__main__":
    main()

# %% [markdown]
# # 提取全部像素数据（保留confidence level）

# %%
import os
import pickle
import time
import numpy as np
import pandas as pd
import geopandas as gpd
import rasterio
import cupy as cp
import matplotlib.pyplot as plt
from tqdm import tqdm
from scipy.stats import gaussian_kde
from shapely.geometry import Point, Polygon
import alphashape
from scipy.spatial.distance import cdist
import pyproj
from shapely.ops import transform
from functools import partial
import math
from pathlib import Path
from rasterio.transform import xy  # Import the xy function

def read_tiff(file_path):
    """Read TIFF file with enhanced debugging"""
    print(f"[DEBUG] Reading TIFF file: {file_path}")
    try:
        with rasterio.open(file_path) as src:
            data = src.read()
            meta = src.meta.copy()
            transform = src.transform
            crs = src.crs
            bounds = src.bounds  # Additional metadata

            print(f"[DEBUG] Bands: {src.count}")
            print(f"[DEBUG] Shape: {data.shape}")
            print(f"[DEBUG] CRS: {crs}")
            print(f"[DEBUG] Bounds: {bounds}")

            return data, meta, transform, crs, bounds
    except RasterioIOError as e:
        print(f"[ERROR] TIFF reading failed: {e}")
        return None

def convert_to_projected_coords(points, source_crs):
    """
    Convert points from source CRS to a suitable UTM projection
    
    Parameters:
    -----------
    points : numpy.ndarray
        Array of shape (n, 2) containing x,y coordinates
    source_crs : str or CRS
        The source coordinate reference system
    
    Returns:
    --------
    projected_points : list
        List of projected coordinates as tuples
    utm_crs : CRS
        The target UTM CRS
    """
    # Check if points array is empty using NumPy's size attribute
    if points.size == 0:
        return [], None
        
    # Convert source_crs to pyproj CRS if it's a string
    if isinstance(source_crs, str):
        source_crs = pyproj.CRS.from_string(source_crs)
    
    # Calculate the centroid of points to determine the appropriate UTM zone
    mean_lon = np.mean(points[:, 0])
    mean_lat = np.mean(points[:, 1])
    
    # Determine UTM zone based on the centroid
    utm_crs = pyproj.CRS.from_dict({
        'proj': 'utm',
        'zone': int((mean_lon + 180) / 6) + 1,
        'south': mean_lat < 0
    })
    
    # Create the transformer
    transformer = pyproj.Transformer.from_crs(source_crs, utm_crs, always_xy=True)
    
    # Transform all points
    x, y = transformer.transform(points[:, 0], points[:, 1])
    
    # Convert to a list of tuples for alphashape
    projected_points = list(zip(x, y))
    
    return projected_points, utm_crs

def extract_building_points(data, transform, min_confidence=0.0):
    """Extract building points with GPU acceleration - now outputs confidence levels directly"""
    print(f"[DEBUG] Extracting building points with minimum confidence > {min_confidence}")
    building_height = data[1]    # Assuming 2nd band is height
    building_confidence = data[2]  # Assuming 3rd band is confidence level
    
    # Use CuPy for faster processing
    try:
        building_confidence_gpu = cp.array(building_confidence)
        building_height_gpu = cp.array(building_height)
        
        # Find valid indices (only filter by minimum confidence if needed)
        valid_indices = cp.where(building_confidence_gpu > min_confidence)
        rows, cols = valid_indices[0].get(), valid_indices[1].get()
    except Exception:
        # Fallback to NumPy
        valid_indices = np.where(building_confidence > min_confidence)
        rows, cols = valid_indices[0], valid_indices[1]
    
    # Extract coordinates, heights, and confidence levels
    points = []
    heights = []
    confidences = []
    
    for i in tqdm(range(len(rows)), desc="Converting pixels"):
        row, col = rows[i], cols[i]
        x, y = rasterio.transform.xy(transform, row, col)
        points.append((x, y))
        heights.append(building_height[row, col])
        confidences.append(building_confidence[row, col])
    
    return points, heights, confidences, rows, cols


def haversine_distance(lat1, lon1, lat2, lon2):
    """Calculate the Haversine distance between two points on Earth"""
    # Convert coordinates to radians
    lat1, lon1, lat2, lon2 = map(np.radians, [lat1, lon1, lat2, lon2])
    
    # Haversine formula
    dlon = lon2 - lon1
    dlat = lat2 - lat1
    
    a = np.sin(dlat/2)**2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon/2)**2
    c = 2 * np.arcsin(np.sqrt(a))
    
    # Radius of Earth in kilometers
    r = 6371
    
    return c * r

def create_full_pixels_dataframe(data, transform, city_center, crs, min_confidence=0.0, output_dir="pixel_data"):
    """
    Create a DataFrame containing all pixels with building confidence levels and height data
    No longer applies threshold - outputs raw confidence values
    """
    print(f"[DEBUG] Creating full pixels DataFrame with minimum confidence = {min_confidence}")

    # Ensure output directory exists
    os.makedirs(output_dir, exist_ok=True)

    # Extract bands
    building_height = data[1]  # Height band (band 2)
    building_confidence = data[2]  # Confidence band (band 3)

    # Get coordinates of all pixels
    rows, cols = np.indices(building_confidence.shape)
    rows = rows.flatten()
    cols = cols.flatten()

    print(f"[DEBUG] Processing {len(rows)} total pixels")

    # Fast batch conversion of pixel indices to coordinates
    xs, ys = xy(transform, rows, cols, offset='center')

    # Batch extract values
    confidence_values = building_confidence[rows, cols]
    height_values = building_height[rows, cols]



    # Calculate distances to city center
    lat_array = ys
    lon_array = xs

    lat1, lon1 = np.radians(lat_array), np.radians(lon_array)
    lat2, lon2 = np.radians(city_center[0]), np.radians(city_center[1])

    dlon = lon2 - lon1
    dlat = lat2 - lat1

    a = np.sin(dlat / 2) ** 2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon / 2) ** 2
    c = 2 * np.arcsin(np.sqrt(a))
    distances = c * 6371  # Earth radius in km

    # Create DataFrame with all metrics - raw confidence and height only
    df_all_pixels = pd.DataFrame({
        'longitude': lon_array,
        'latitude': lat_array,
        'row': rows,
        'col': cols,
        'building_confidence': confidence_values,  # Raw confidence level (0-1)
        'building_height': height_values,
        'distance_to_center': distances
    })

    return df_all_pixels


def process_city(tiff_file, city_name, year, city_center, min_confidence=0.0):
    """Process a single city's TIFF file - now outputs confidence levels directly"""
    print(f"[INFO] Processing {city_name} {year} with minimum confidence {min_confidence}")
    
    try:
        # Create output directories
        output_dirs = ["pixel_data", "visualizations"]
        for directory in output_dirs:
            os.makedirs(directory, exist_ok=True)
        
        # Read TIFF
        print("[DEBUG] Reading TIFF file...")
        result = read_tiff(tiff_file)
        if result is not None:
            data, meta, transform, crs, bounds = result
            # Proceed with processing the data
        else:
            # Handle the error case
            print("Failed to read the TIFF file.")
            return False
        
        # Create full pixels DataFrame with confidence levels
        df_all_pixels = create_full_pixels_dataframe(data, transform, city_center, crs, min_confidence=min_confidence)
        
        # Save the all pixels dataframe with city and year info
        all_pixels_output_file = os.path.join("pixel_data", f"{city_name}_{year}_all_pixels_confidence.csv")
        df_all_pixels.to_csv(all_pixels_output_file, index=False)
        print(f"[DEBUG] Saved {len(df_all_pixels)} total pixels to {all_pixels_output_file}")
        
        # Print confidence statistics
        confidence_stats = df_all_pixels['building_confidence'].describe()
        print(f"[INFO] Building confidence statistics:")
        print(confidence_stats)
        
        print(f"[INFO] {city_name} {year} analysis completed successfully!")
        return True
        
    except Exception as e:
        print(f"[ERROR] An error occurred while processing {city_name} {year}: {e}")
        import traceback
        traceback.print_exc()
        return False

# %%
def main():
    """Process multiple cities and years"""
    
    # Default minimum confidence for filtering (0.0 means no filtering)
    min_confidence = 0.0
    
    # Process each city and year
    results = []
    for city_name, years, city_center in cities:
        for year in years:
            # Construct TIFF file path
            tiff_file = f"images/{city_name}_{year}.tif"
            
            # Check if file exists
            if not os.path.exists(tiff_file):
                print(f"[WARNING] TIFF file not found: {tiff_file}")
                continue
            
            # Process city with specified minimum confidence
            success = process_city(tiff_file, city_name, year, city_center, min_confidence=min_confidence)
            results.append({
                "city": city_name,
                "year": year,
                "success": success
            })
    
    # Print summary
    print("\n[SUMMARY] Processing Results:")
    for result in results:
        status = "SUCCESS" if result["success"] else "FAILED"
        print(f"  {result['city']} {result['year']}: {status}")

if __name__ == "__main__":
    main()
